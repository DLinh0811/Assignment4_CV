# %% [markdown]
# # Computer Vision 2024 Assignment 3: Deep Learning for Perception Tasks
#
# This assignment contains 2 questions. The first question probes understanding of deep learning for classification. The second question is a more challenging classification experiment on a larger dataset. Answer the questions in separate Python notebooks.
#
# ## Question 1: A simple classifier, 20 marks
#
# For this exercise, we provide demo code showing how to train a network on a small dataset called [Fashion-MNIST](https://github.com/zalandoresearch/fashion-mnist). Please run through the code "tutorial-style" to get a sense of what it is doing. Then use the code alongside lecture notes and other resources to understand how to use pytorch libraries to implement, train and use a neural network.
#
# For the Fashion-MNIST dataset the lables from 0-9 correspond to various clothing classes so you might find it convenient to create a python list as follows:
#
# class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
#                'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']
#
# You will need to answer various questions about the system, how it operates, the results of experiments with it and make modifications to it yourself. You can change the training scheme and the network structure.
#
# Organize your own text and code cell to show the answer of each questions.
#
# Detailed requirements:
#
# **Q1.1 (1 point)**
#
# Extract 3 images of different types of clothing from the training dataset, print out the size/shape of the training images, and display the three with their corresponding labels.
#
# **Q1.2 (2 points)**
#
# Run the training code for 10 epochs, for different values of the learning rate. Fill in the table below and plot the loss curves for each experiment:
#
# |Lr|Accuracy|
# |---|---|
# |1   |      |
# |0.1|          |
# |0.01|         ||
# |0.001  |        |
#
#
# **Q1.3 (3 points)**
#
# Report the number of epochs when the accuracy reaches 85%. Fill in the table below and plot the loass curve for each experiment:
#
# |Lr|Accuracy|Epoch|
# |---|---|---|
# |1   |      |     |
# |0.1|          |    |
# |0.01|         |    |
# |0.001  |        |     |
#
#
# **Q1.4 (2 points)**
#
# Compare the results in table 1 and table 2, what is your observation and your understanding of learning rate?
#
#
# **Q1.5 (5 points)**
#
# Build a wider network by modifying the code that constructs the network so that the hidden layer(s) contain more perceptrons, and record the accuracy along with the number of trainable parameters in your model.  Now modify the oroginal network to be deeper instead of wider (i.e. by adding more hidden layers). Record your accuracy and network size findings. Plot the loss curve for each experiment. Write down your conclusions about changing the network structure?
#
# |Structures|Accuracy|Parameters|
# |---|---|---|
# |Base   |      ||
# |Deeper|          ||
# |Wider|         ||
#
#
# **Q1.6 (2 points)**
#
# Calculate the mean of the gradients of the loss to all trainable parameters. Plot the gradients curve for the first 100 training steps. What are your observations? Note that this gradients will be saved with the training weight automatically after you call loss.backwards(). Hint: the mean of the gradients decrease.
#
# For more exlanation of q1.7, you could refer to the following simple instructions: https://colab.research.google.com/drive/1XAsyNegGSvMf3_B6MrsXht7-fHqtJ7OW?usp=sharing
#
# **Q1.7 (5 points)**
#
# Modify the network structure and training/test to use a small convolutional neural network instead of an MLP. Discuss your findings with rehgard to convergence, accuracy and number of parameters, relative to MLPs.
#
# Hint: Look at the structure of the CNN in the Workshop 3 examples.

# %% [markdown]
# Add in a code cell to inspect the training data, as per Q1.1. Each element of the training_data structure has a greyscale image (which you can use plt.imshow(img[0,:,:]) to display, just like you did in previous assignments.

# %%
import numpy as np # This is for mathematical operations

# this is used in plotting 
import matplotlib.pyplot as plt 
import time
import pylab as pl
from IPython import display

# %matplotlib inline

# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload

# %%
#### Tutorial Code
####PyTorch has two primitives to work with data: torch.utils.data.DataLoader and torch.utils.data.Dataset. 
#####Dataset stores samples and their corresponding labels, and DataLoader wraps an iterable around the Dataset.
import torch
from torch import nn
from torch.utils.data import DataLoader
from torchvision import datasets
from torchvision.transforms import ToTensor, Lambda, Compose
import matplotlib.pyplot as plt

# Download training data from open datasets. 
##Every TorchVision Dataset includes two arguments: 
##transform and target_transform to modify the samples and labels respectively.

training_data = datasets.FashionMNIST(
    root="data",
    train=True,
    download=True,
    transform=ToTensor(),
)

# Download test data from open datasets.
test_data = datasets.FashionMNIST(
    root="data",
    train=False,
    download=True,
    transform=ToTensor(),
)

# %% [markdown]
# **NOTE**: For consistency with the original data set, we call our validation data "test_data". It is important to keep in mind though that we are using the data for model validation and not for testing the final, trained model (which requires data not used when training the model parameters).
#
# We pass the Dataset as an argument to DataLoader. This wraps an iterable over our dataset and supports automatic batching, sampling, shuffling, and multiprocess data loading. Here we define a batch size of 64, i.e. each element in the dataloader iterable will return a batch of 64 features and labels.

# %% [markdown]
# **Q1.1**
#
# - Extract 3 images of different types of clothing from the training dataset
# - Print out the size/shape of the training images, and display the three with their corresponding labels.

# %%
# Select 3 images of different types of clothing

indices = [0,1,2]

images, lables = zip(*(training_data[i] for i in indices)) # Return 2 tuples

# Get the size/shape of images

image_shape = (image.shape for image in images)

# Print the shapes of the selecyed images
# Define class name
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

label_shape = zip(lables, images)

for label, shape in label_shape:
    print(f'Image label {class_names[label]}: {shape}')
    print("\n") # For better visualization


# Display the three images with their corresponding labels
plt.figure(figsize=(10, 3))
for i, (image, label) in enumerate(zip(images, lables)):
    plt.subplot(1,3,i + 1)
    plt.title(class_names[label])
    plt.imshow(image.squeeze(), cmap="gray")
    plt.axis('off')
    print(f"Image {i+1} size: {image.size()}")
plt.show()
# Out:
# Image label Ankle boot: tensor([[[0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0039, 0.0000, 0.0000, 0.0510,
#           0.2863, 0.0000, 0.0000, 0.0039, 0.0157, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0039, 0.0039, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0118, 0.0000, 0.1412, 0.5333,
#           0.4980, 0.2431, 0.2118, 0.0000, 0.0000, 0.0000, 0.0039, 0.0118,
#           0.0157, 0.0000, 0.0000, 0.0118],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0235, 0.0000, 0.4000, 0.8000,
#           0.6902, 0.5255, 0.5647, 0.4824, 0.0902, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0471, 0.0392, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.6078, 0.9255,
#           0.8118, 0.6980, 0.4196, 0.6118, 0.6314, 0.4275, 0.2510, 0.0902,
#           0.3020, 0.5098, 0.2824, 0.0588],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0039, 0.0000, 0.2706, 0.8118, 0.8745,
#           0.8549, 0.8471, 0.8471, 0.6392, 0.4980, 0.4745, 0.4784, 0.5725,
#           0.5529, 0.3451, 0.6745, 0.2588],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0039, 0.0039, 0.0039, 0.0000, 0.7843, 0.9098, 0.9098,
#           0.9137, 0.8980, 0.8745, 0.8745, 0.8431, 0.8353, 0.6431, 0.4980,
#           0.4824, 0.7686, 0.8980, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.7176, 0.8824, 0.8471,
#           0.8745, 0.8941, 0.9216, 0.8902, 0.8784, 0.8706, 0.8784, 0.8667,
#           0.8745, 0.9608, 0.6784, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.7569, 0.8941, 0.8549,
#           0.8353, 0.7765, 0.7059, 0.8314, 0.8235, 0.8275, 0.8353, 0.8745,
#           0.8627, 0.9529, 0.7922, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0039, 0.0118, 0.0000, 0.0471, 0.8588, 0.8627, 0.8314,
#           0.8549, 0.7529, 0.6627, 0.8902, 0.8157, 0.8549, 0.8784, 0.8314,
#           0.8863, 0.7725, 0.8196, 0.2039],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0235, 0.0000, 0.3882, 0.9569, 0.8706, 0.8627,
#           0.8549, 0.7961, 0.7765, 0.8667, 0.8431, 0.8353, 0.8706, 0.8627,
#           0.9608, 0.4667, 0.6549, 0.2196],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0157, 0.0000, 0.0000, 0.2157, 0.9255, 0.8941, 0.9020,
#           0.8941, 0.9412, 0.9098, 0.8353, 0.8549, 0.8745, 0.9176, 0.8510,
#           0.8510, 0.8196, 0.3608, 0.0000],
#          [0.0000, 0.0000, 0.0039, 0.0157, 0.0235, 0.0275, 0.0078, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.9294, 0.8863, 0.8510, 0.8745,
#           0.8706, 0.8588, 0.8706, 0.8667, 0.8471, 0.8745, 0.8980, 0.8431,
#           0.8549, 1.0000, 0.3020, 0.0000],
#          [0.0000, 0.0118, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.2431, 0.5686, 0.8000, 0.8941, 0.8118, 0.8353, 0.8667,
#           0.8549, 0.8157, 0.8275, 0.8549, 0.8784, 0.8745, 0.8588, 0.8431,
#           0.8784, 0.9569, 0.6235, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0706, 0.1725, 0.3216, 0.4196,
#           0.7412, 0.8941, 0.8627, 0.8706, 0.8510, 0.8863, 0.7843, 0.8039,
#           0.8275, 0.9020, 0.8784, 0.9176, 0.6902, 0.7373, 0.9804, 0.9725,
#           0.9137, 0.9333, 0.8431, 0.0000],
#          [0.0000, 0.2235, 0.7333, 0.8157, 0.8784, 0.8667, 0.8784, 0.8157,
#           0.8000, 0.8392, 0.8157, 0.8196, 0.7843, 0.6235, 0.9608, 0.7569,
#           0.8078, 0.8745, 1.0000, 1.0000, 0.8667, 0.9176, 0.8667, 0.8275,
#           0.8627, 0.9098, 0.9647, 0.0000],
#          [0.0118, 0.7922, 0.8941, 0.8784, 0.8667, 0.8275, 0.8275, 0.8392,
#           0.8039, 0.8039, 0.8039, 0.8627, 0.9412, 0.3137, 0.5882, 1.0000,
#           0.8980, 0.8667, 0.7373, 0.6039, 0.7490, 0.8235, 0.8000, 0.8196,
#           0.8706, 0.8941, 0.8824, 0.0000],
#          [0.3843, 0.9137, 0.7765, 0.8235, 0.8706, 0.8980, 0.8980, 0.9176,
#           0.9765, 0.8627, 0.7608, 0.8431, 0.8510, 0.9451, 0.2549, 0.2863,
#           0.4157, 0.4588, 0.6588, 0.8588, 0.8667, 0.8431, 0.8510, 0.8745,
#           0.8745, 0.8784, 0.8980, 0.1137],
#          [0.2941, 0.8000, 0.8314, 0.8000, 0.7569, 0.8039, 0.8275, 0.8824,
#           0.8471, 0.7255, 0.7725, 0.8078, 0.7765, 0.8353, 0.9412, 0.7647,
#           0.8902, 0.9608, 0.9373, 0.8745, 0.8549, 0.8314, 0.8196, 0.8706,
#           0.8627, 0.8667, 0.9020, 0.2627],
#          [0.1882, 0.7961, 0.7176, 0.7608, 0.8353, 0.7725, 0.7255, 0.7451,
#           0.7608, 0.7529, 0.7922, 0.8392, 0.8588, 0.8667, 0.8627, 0.9255,
#           0.8824, 0.8471, 0.7804, 0.8078, 0.7294, 0.7098, 0.6941, 0.6745,
#           0.7098, 0.8039, 0.8078, 0.4510],
#          [0.0000, 0.4784, 0.8588, 0.7569, 0.7020, 0.6706, 0.7176, 0.7686,
#           0.8000, 0.8235, 0.8353, 0.8118, 0.8275, 0.8235, 0.7843, 0.7686,
#           0.7608, 0.7490, 0.7647, 0.7490, 0.7765, 0.7529, 0.6902, 0.6118,
#           0.6549, 0.6941, 0.8235, 0.3608],
#          [0.0000, 0.0000, 0.2902, 0.7412, 0.8314, 0.7490, 0.6863, 0.6745,
#           0.6863, 0.7098, 0.7255, 0.7373, 0.7412, 0.7373, 0.7569, 0.7765,
#           0.8000, 0.8196, 0.8235, 0.8235, 0.8275, 0.7373, 0.7373, 0.7608,
#           0.7529, 0.8471, 0.6667, 0.0000],
#          [0.0078, 0.0000, 0.0000, 0.0000, 0.2588, 0.7843, 0.8706, 0.9294,
#           0.9373, 0.9490, 0.9647, 0.9529, 0.9569, 0.8667, 0.8627, 0.7569,
#           0.7490, 0.7020, 0.7137, 0.7137, 0.7098, 0.6902, 0.6510, 0.6588,
#           0.3882, 0.2275, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.1569,
#           0.2392, 0.1725, 0.2824, 0.1608, 0.1373, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000]]])
#
#
# Image label T-shirt/top: tensor([[[0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0039, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.1608, 0.7373, 0.4039, 0.2118, 0.1882, 0.1686,
#           0.3412, 0.6588, 0.5216, 0.0627, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0039, 0.0000, 0.0000, 0.0000, 0.1922,
#           0.5333, 0.8588, 0.8471, 0.8941, 0.9255, 1.0000, 1.0000, 1.0000,
#           1.0000, 0.8510, 0.8431, 0.9961, 0.9059, 0.6275, 0.1765, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0549, 0.6902, 0.8706,
#           0.8784, 0.8314, 0.7961, 0.7765, 0.7686, 0.7843, 0.8431, 0.8000,
#           0.7922, 0.7882, 0.7882, 0.7882, 0.8196, 0.8549, 0.8784, 0.6431,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.7373, 0.8588, 0.7843,
#           0.7765, 0.7922, 0.7765, 0.7804, 0.7804, 0.7882, 0.7686, 0.7765,
#           0.7765, 0.7843, 0.7843, 0.7843, 0.7843, 0.7882, 0.7843, 0.8824,
#           0.1608, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.2000, 0.8588, 0.7804, 0.7961,
#           0.7961, 0.8314, 0.9333, 0.9725, 0.9804, 0.9608, 0.9765, 0.9647,
#           0.9686, 0.9882, 0.9725, 0.9216, 0.8118, 0.7961, 0.7961, 0.8706,
#           0.5490, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.4549, 0.8863, 0.8078, 0.8000,
#           0.8118, 0.8000, 0.3961, 0.2941, 0.1843, 0.2863, 0.1882, 0.1961,
#           0.1765, 0.2000, 0.2471, 0.4431, 0.8706, 0.7922, 0.8078, 0.8627,
#           0.8784, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.7843, 0.8706, 0.8196, 0.7961,
#           0.8431, 0.7843, 0.0000, 0.2745, 0.3843, 0.0000, 0.4039, 0.2314,
#           0.2667, 0.2784, 0.1922, 0.0000, 0.8588, 0.8078, 0.8392, 0.8235,
#           0.9804, 0.1490, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.9686, 0.8549, 0.8314, 0.8235,
#           0.8431, 0.8392, 0.0000, 0.9961, 0.9529, 0.5451, 1.0000, 0.6824,
#           0.9843, 1.0000, 0.8039, 0.0000, 0.8431, 0.8510, 0.8392, 0.8157,
#           0.8627, 0.3725, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.1765, 0.8863, 0.8392, 0.8392, 0.8431,
#           0.8784, 0.8039, 0.0000, 0.1647, 0.1373, 0.2353, 0.0627, 0.0667,
#           0.0471, 0.0510, 0.2745, 0.0000, 0.7412, 0.8471, 0.8314, 0.8078,
#           0.8314, 0.6118, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.6431, 0.9216, 0.8392, 0.8275, 0.8627,
#           0.8471, 0.7882, 0.2039, 0.2784, 0.3490, 0.3686, 0.3255, 0.3059,
#           0.2745, 0.2980, 0.3608, 0.3412, 0.8078, 0.8118, 0.8706, 0.8353,
#           0.8588, 0.8157, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.4157, 0.7333, 0.8745, 0.9294, 0.9725,
#           0.8275, 0.7765, 0.9882, 0.9804, 0.9725, 0.9608, 0.9725, 0.9882,
#           0.9922, 0.9804, 0.9882, 0.9373, 0.7882, 0.8314, 0.8824, 0.8431,
#           0.7569, 0.4431, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0667, 0.2118, 0.6235,
#           0.8706, 0.7569, 0.8157, 0.7529, 0.7725, 0.7843, 0.7843, 0.7843,
#           0.7843, 0.7882, 0.7961, 0.7647, 0.8235, 0.6471, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.1843,
#           0.8824, 0.7529, 0.8392, 0.7961, 0.8078, 0.8000, 0.8000, 0.8039,
#           0.8078, 0.8000, 0.8314, 0.7725, 0.8549, 0.4196, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0039, 0.0235, 0.0000, 0.1804,
#           0.8314, 0.7647, 0.8314, 0.7922, 0.8078, 0.8039, 0.8000, 0.8039,
#           0.8078, 0.8000, 0.8314, 0.7843, 0.8549, 0.3569, 0.0000, 0.0118,
#           0.0039, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0039, 0.0000, 0.0431,
#           0.7725, 0.7804, 0.8039, 0.7922, 0.8039, 0.8078, 0.8000, 0.8039,
#           0.8118, 0.8000, 0.8039, 0.8039, 0.8549, 0.3020, 0.0000, 0.0196,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0118, 0.0000, 0.0078,
#           0.7490, 0.7765, 0.7882, 0.8039, 0.8078, 0.8039, 0.8039, 0.8078,
#           0.8196, 0.8078, 0.7804, 0.8196, 0.8588, 0.2902, 0.0000, 0.0196,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0078, 0.0000, 0.0000,
#           0.7373, 0.7725, 0.7843, 0.8118, 0.8118, 0.8000, 0.8118, 0.8118,
#           0.8235, 0.8157, 0.7765, 0.8118, 0.8667, 0.2824, 0.0000, 0.0157,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0078, 0.0000, 0.0000,
#           0.8431, 0.7765, 0.7961, 0.8078, 0.8157, 0.8039, 0.8118, 0.8118,
#           0.8235, 0.8157, 0.7843, 0.7922, 0.8706, 0.2941, 0.0000, 0.0157,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0039, 0.0000, 0.0000,
#           0.8314, 0.7765, 0.8196, 0.8078, 0.8196, 0.8078, 0.8157, 0.8118,
#           0.8275, 0.8078, 0.8039, 0.7765, 0.8667, 0.3137, 0.0000, 0.0118,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0039, 0.0000, 0.0000,
#           0.8000, 0.7882, 0.8039, 0.8157, 0.8118, 0.8039, 0.8275, 0.8039,
#           0.8235, 0.8235, 0.8196, 0.7647, 0.8667, 0.3765, 0.0000, 0.0118,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0039, 0.0000, 0.0000,
#           0.7922, 0.7882, 0.8039, 0.8196, 0.8118, 0.8039, 0.8353, 0.8078,
#           0.8235, 0.8196, 0.8235, 0.7608, 0.8510, 0.4118, 0.0000, 0.0078,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0039, 0.0000, 0.0000,
#           0.8000, 0.8000, 0.8039, 0.8157, 0.8118, 0.8039, 0.8431, 0.8118,
#           0.8235, 0.8157, 0.8275, 0.7569, 0.8353, 0.4510, 0.0000, 0.0078,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.8000, 0.8118, 0.8118, 0.8157, 0.8078, 0.8078, 0.8431, 0.8235,
#           0.8235, 0.8118, 0.8314, 0.7647, 0.8235, 0.4627, 0.0000, 0.0078,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0039, 0.0000, 0.0000,
#           0.7765, 0.8157, 0.8157, 0.8157, 0.8000, 0.8118, 0.8314, 0.8314,
#           0.8235, 0.8118, 0.8275, 0.7686, 0.8118, 0.4745, 0.0000, 0.0039,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0039, 0.0000, 0.0000,
#           0.7765, 0.8235, 0.8118, 0.8157, 0.8078, 0.8196, 0.8353, 0.8314,
#           0.8275, 0.8118, 0.8235, 0.7725, 0.8118, 0.4863, 0.0000, 0.0039,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.6745, 0.8235, 0.7961, 0.7882, 0.7804, 0.8000, 0.8118, 0.8039,
#           0.8000, 0.7882, 0.8039, 0.7725, 0.8078, 0.4980, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.7373, 0.8667, 0.8392, 0.9176, 0.9255, 0.9333, 0.9569, 0.9569,
#           0.9569, 0.9412, 0.9529, 0.8392, 0.8784, 0.6353, 0.0000, 0.0078,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0039, 0.0000, 0.0000,
#           0.5451, 0.5725, 0.5098, 0.5294, 0.5294, 0.5373, 0.4902, 0.4863,
#           0.4902, 0.4745, 0.4667, 0.4471, 0.5098, 0.2980, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000]]])
#
#
# Image label T-shirt/top: tensor([[[0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0863, 0.4627, 0.0941, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.1882, 0.3451, 0.0196, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0471, 0.3922, 0.8314, 0.8039, 0.7255, 0.7020, 0.6784, 0.7294,
#           0.7569, 0.8667, 0.5569, 0.3333, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.3333, 0.2980, 0.7804, 0.8824, 0.9725, 1.0000, 0.9333,
#           0.8863, 0.6157, 0.2667, 0.3137, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.3569, 0.2706, 0.3569, 0.7882, 0.8549, 0.8824, 0.8196,
#           0.6196, 0.2392, 0.3647, 0.2824, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.3098, 0.3490, 0.2392, 0.2314, 0.3412, 0.4235, 0.2941,
#           0.2196, 0.2980, 0.3804, 0.2863, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.2941, 0.3490, 0.3137, 0.3137, 0.2627, 0.2471, 0.2863,
#           0.3255, 0.3137, 0.3765, 0.2824, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.3020, 0.3451, 0.3020, 0.3137, 0.3255, 0.3255, 0.3255,
#           0.3255, 0.3176, 0.3725, 0.2980, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.3490, 0.3765, 0.3137, 0.3255, 0.3176, 0.3294, 0.3333,
#           0.3333, 0.3333, 0.3804, 0.3294, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.3647, 0.3804, 0.3176, 0.3333, 0.3294, 0.3333, 0.3412,
#           0.3451, 0.3294, 0.3882, 0.3412, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.3725, 0.3412, 0.3294, 0.3412, 0.3451, 0.3333, 0.3412,
#           0.3412, 0.3294, 0.3608, 0.3412, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.3804, 0.3412, 0.3412, 0.3333, 0.3451, 0.3412, 0.3412,
#           0.3412, 0.3451, 0.3333, 0.4196, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0667, 0.3922, 0.3451, 0.3412, 0.3412, 0.3451, 0.3412, 0.3412,
#           0.3333, 0.3490, 0.3020, 0.4627, 0.0314, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0392, 0.3647, 0.3412, 0.3412, 0.3412, 0.3412, 0.3412, 0.3451,
#           0.3412, 0.3490, 0.3137, 0.4039, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0353, 0.3765, 0.3412, 0.3412, 0.3412, 0.3412, 0.3412, 0.3451,
#           0.3412, 0.3451, 0.3412, 0.4039, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0471, 0.3765, 0.3333, 0.3412, 0.3412, 0.3412, 0.3333, 0.3412,
#           0.3412, 0.3451, 0.3490, 0.3922, 0.0078, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0784, 0.3725, 0.3294, 0.3451, 0.3333, 0.3412, 0.3451, 0.3451,
#           0.3451, 0.3490, 0.3451, 0.3882, 0.0314, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0824, 0.3765, 0.3333, 0.3412, 0.3333, 0.3451, 0.3451, 0.3451,
#           0.3451, 0.3490, 0.3490, 0.3882, 0.0392, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0941, 0.3765, 0.3333, 0.3412, 0.3333, 0.3412, 0.3451, 0.3451,
#           0.3490, 0.3451, 0.3569, 0.4000, 0.0549, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0980, 0.3647, 0.3294, 0.3451, 0.3412, 0.3412, 0.3412, 0.3412,
#           0.3412, 0.3490, 0.3569, 0.4039, 0.1137, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.1176, 0.3725, 0.3333, 0.3451, 0.3451, 0.3412, 0.3412, 0.3412,
#           0.3412, 0.3490, 0.3451, 0.4000, 0.1451, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.1333, 0.3765, 0.3451, 0.3412, 0.3412, 0.3412, 0.3412, 0.3412,
#           0.3412, 0.3333, 0.3333, 0.3804, 0.1490, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.1569, 0.3765, 0.3412, 0.3333, 0.3412, 0.3412, 0.3412, 0.3412,
#           0.3412, 0.3333, 0.3294, 0.3608, 0.1922, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.1804, 0.3725, 0.3255, 0.3294, 0.3412, 0.3412, 0.3412, 0.3412,
#           0.3412, 0.3412, 0.3294, 0.3412, 0.3294, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.2824, 0.3725, 0.3333, 0.3294, 0.3333, 0.3451, 0.3412, 0.3412,
#           0.3490, 0.3412, 0.3333, 0.3255, 0.2471, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.2510, 0.3922, 0.3294, 0.3412, 0.3451, 0.3333, 0.3451, 0.3451,
#           0.3294, 0.3412, 0.3255, 0.3725, 0.2078, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0392, 0.4000, 0.3922, 0.3569, 0.3569, 0.3490, 0.3333, 0.3294,
#           0.3294, 0.3412, 0.4235, 0.4157, 0.0549, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0314, 0.2863, 0.3647, 0.4078, 0.4196, 0.4039, 0.4039,
#           0.4157, 0.4000, 0.2941, 0.0392, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0039, 0.0000, 0.0000, 0.0000, 0.0706, 0.1647, 0.2235, 0.2196,
#           0.1255, 0.0314, 0.0000, 0.0000, 0.0039, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000]]])
#
#
# Image 1 size: torch.Size([1, 28, 28])
# Image 2 size: torch.Size([1, 28, 28])
# Image 3 size: torch.Size([1, 28, 28])

# %% [markdown]
# **Result analysis**
#
# ***Tensor representation***
#
# *- Pixel values:*
#
# The tensor representation of images denotes pixel values. Here, we can observe:
# The values within the tensor are floating-point numbers between 0 and 1. These values represent pixel intensities:
#
# 0.0000 typically represents black.
#
# 1.0000 represents white.
#
# Values between 0.0000 and 1.0000 represent varying shades of gray.
#
# *- Tensor shape:*
#
#
# ```
# Image 1 size: torch.Size([1, 28, 28])
# Image 2 size: torch.Size([1, 28, 28])
# Image 3 size: torch.Size([1, 28, 28])
# ```
# Each image has the shape `[1, 28, 28]`, indicating that they are grayscale images with dimensions 28x28 pixels. The first dimension is 1, which is typical for single-channel grayscale images.

# %%
batch_size = 64

# Create data loaders.
train_dataloader = DataLoader(training_data, batch_size=batch_size)
test_dataloader = DataLoader(test_data, batch_size=batch_size)

for X, y in test_dataloader:
    print("Shape of X [N, C, H, W]: ", X.shape)
    print("Shape of y: ", y.shape, y.dtype)
    break
# Out:
# Shape of X [N, C, H, W]:  torch.Size([64, 1, 28, 28])
# Shape of y:  torch.Size([64]) torch.int64

# %% [markdown]
# To define a neural network in PyTorch, we create a class that inherits from nn.Module. We define the layers of the network in the init function and specify how data will pass through the network in the forward function. To accelerate operations in the neural network, we move it to the GPU if available.

# %%
# Set the seed for reproducibility
import random
def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)
        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = False

# Call the set_seed function
set_seed(42)

# %%
# Get cpu or gpu device for training.
device = "cuda" if torch.cuda.is_available() else "cpu"
print("Using {} device".format(device))

import torch.nn.functional as F

# Define model
class NeuralNetwork(nn.Module):
    def __init__(self):
        super(NeuralNetwork, self).__init__()
        self.flatten = nn.Flatten()
        self.linear_relu_stack = nn.Sequential(
            nn.Linear(28*28, 512),
            nn.ReLU(),
            nn.Linear(512, 512),
            nn.ReLU(),
            nn.Linear(512, 10)
       )

    def forward(self, x):
        x = self.flatten(x)
        logits = self.linear_relu_stack(x)

        return logits

model = NeuralNetwork().to(device)
print(model)
# Out:
# Using cuda device
# NeuralNetwork(
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=784, out_features=512, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=512, out_features=512, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=512, out_features=10, bias=True)
#   )
# )

# %%
###Define the loss function and the optimizer
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=1e-3)

# %% [markdown]
# In a single training loop, the model makes predictions on the training dataset (fed to it in batches), and backpropagates the prediction error to adjust the model’s parameters.

# %%
def train(dataloader, model, loss_fn, optimizer):
    size = len(dataloader.dataset)
    model.train()
    train_losses = []
    for batch, (X, y) in enumerate(dataloader):
        X, y = X.to(device), y.to(device)

        # Compute prediction error
        pred = model(X)
        loss = loss_fn(pred, y)

        # Backpropagation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        train_losses.append(loss.item())

        if batch % 100 == 0:
            loss, current = loss.item(), batch * len(X)
            print(f"loss: {loss:>7f}  [{current:>5d}/{size:>5d}]")

    train_loss = sum(train_losses) / len(train_losses)
    print(f'Average Train loss: {train_loss:>5f}')

    return train_loss

# %%
##Define a test function
def test(dataloader, model, loss_fn):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    model.eval()
    test_loss, correct = 0, 0
    with torch.no_grad():
        for X, y in dataloader:
            X, y = X.to(device), y.to(device)
            pred = model(X)
            test_loss += loss_fn(pred, y).item()
            correct += (pred.argmax(1) == y).type(torch.float).sum().item()
    test_loss /= num_batches
    correct /= size
    print(f"Test Error: \n Accuracy: {(100*correct):>0.1f}%, Avg loss: {test_loss:>8f} \n")

    return test_loss, correct

# %% [markdown]
# **Modification for function `test(dataloader, model, loss_fn):`**
#
# - Returned values: `test loss` - For later plotting tess loss curve
#
# - Returned values: `correct` - The accuracy of the implemented test

# %% [markdown]
# **Q1.2 (2 points)**
#
# Run the training code for 10 epochs, for different values of the learning rate. Fill in the table below and plot the loss curves for each experiment:
#
# |Lr|Accuracy|
# |---|---|
# |1   |      |
# |0.1|          |
# |0.01|         ||
# |0.001  |        |

# %% [markdown]
# Before running the training code for 10 epoches with different parameters, we can define a function for reusability

# %%
def train_and_test(lr, epochs = 10):
    # Set the default random seed 42
    set_seed(42)

    # Print the experminent learning rate
    print(f'Learning rate: {lr}\n{'-' * 30}')

    # Initialize model, loss function, and optimizer
    model = NeuralNetwork().to(device)
    loss_fn = nn.CrossEntropyLoss()
    optimizer = torch.optim.SGD(model.parameters(), lr=lr)

    # Track training and testing loss for plotting
    train_losses = []
    test_losses = []
    accuracies = []
    
    for t in range(epochs):
        print(f"Epoch {t+1}\n{'-' * 30}")
        train_loss = train(train_dataloader, model, loss_fn, optimizer)
        test_loss, correct = test(test_dataloader, model, loss_fn)
        
        train_losses.append(train_loss)
        test_losses.append(test_loss)
        accuracies.append(correct)
    
    print(f'Accuracy after {epochs} epochs: {correct}')
    print('Finish running!')
    return train_losses, test_losses, accuracies

# %%
# Initiate different learning rates 
learning_rates = [1, 0.1, 0.01, 0.001]
results = {}

for lr in learning_rates:
    print(f"Training with learning rate: {lr}")
    train_losses, test_losses, accuracy_list = train_and_test(lr, epochs=10) # train data with epoch = 10
    results[lr] = {
        'train_losses': train_losses,
        'test_losses': test_losses,
        'accuracy_list': accuracy_list
    }
# Out:
# Training with learning rate: 1
# Learning rate: 1
# ------------------------------
# Epoch 1
# ------------------------------
# loss: 2.298730  [    0/60000]
# loss: 2.078346  [ 6400/60000]
# loss: 2.063327  [12800/60000]
# loss: 1.884854  [19200/60000]
# loss: 1.656733  [25600/60000]
# loss: 1.679165  [32000/60000]
# loss: 1.421637  [38400/60000]
# loss: 1.532273  [44800/60000]
# loss: 1.777356  [51200/60000]
# loss: 1.685938  [57600/60000]
# Average Train loss: 1.880750
# Test Error:
#  Accuracy: 20.0%, Avg loss: 1.915828
#
# Epoch 2
# ------------------------------
# loss: 1.966882  [    0/60000]
# loss: 1.915499  [ 6400/60000]
# loss: 1.766465  [12800/60000]
# loss: 1.752323  [19200/60000]
# loss: 1.623561  [25600/60000]
# loss: 1.487857  [32000/60000]
# loss: 1.413146  [38400/60000]
# loss: 1.680380  [44800/60000]
# loss: 1.637021  [51200/60000]
# loss: 1.469961  [57600/60000]
# Average Train loss: 1.699385
# Test Error:
#  Accuracy: 28.6%, Avg loss: 1.493816
#
# Epoch 3
# ------------------------------
# loss: 1.612844  [    0/60000]
# loss: 1.632038  [ 6400/60000]
# loss: 1.441342  [12800/60000]
# loss: 1.812690  [19200/60000]
# loss: 1.686181  [25600/60000]
# loss: 1.731072  [32000/60000]
# loss: 1.489014  [38400/60000]
# loss: 3.103043  [44800/60000]
# loss: 1.750626  [51200/60000]
# loss: 1.516080  [57600/60000]
# Average Train loss: 4.268775
# Test Error:
#  Accuracy: 30.1%, Avg loss: 1.626754
#
# Epoch 4
# ------------------------------
# loss: 1.564310  [    0/60000]
# loss: 1.492587  [ 6400/60000]
# loss: 1.595447  [12800/60000]
# loss: 1.654886  [19200/60000]
# loss: 1.527521  [25600/60000]
# loss: 2.173019  [32000/60000]
# loss: 1.356197  [38400/60000]
# loss: 1.455516  [44800/60000]
# loss: 1.712601  [51200/60000]
# loss: 1.722220  [57600/60000]
# Average Train loss: 1.694534
# Test Error:
#  Accuracy: 19.8%, Avg loss: 1.747444
#
# Epoch 5
# ------------------------------
# loss: 1.787047  [    0/60000]
# loss: 2.313029  [ 6400/60000]
# loss: 1.856514  [12800/60000]
# loss: 2.268281  [19200/60000]
# loss: 2.265279  [25600/60000]
# loss: 2.125515  [32000/60000]
# loss: 2.295030  [38400/60000]
# loss: 1.759692  [44800/60000]
# loss: 2.272519  [51200/60000]
# loss: 1.574183  [57600/60000]
# Average Train loss: 155.936189
# Test Error:
#  Accuracy: 10.1%, Avg loss: 2.309788
#
# Epoch 6
# ------------------------------
# loss: 2.314454  [    0/60000]
# loss: 2.314639  [ 6400/60000]
# loss: 2.350553  [12800/60000]
# loss: 2.509769  [19200/60000]
# loss: 1.626091  [25600/60000]
# loss: 1.773114  [32000/60000]
# loss: 2.303272  [38400/60000]
# loss: 2.288610  [44800/60000]
# loss: 2.300421  [51200/60000]
# loss: 2.330204  [57600/60000]
# Average Train loss: 2.270584
# Test Error:
#  Accuracy: 10.0%, Avg loss: 2.305845
#
# Epoch 7
# ------------------------------
# loss: 2.313043  [    0/60000]
# loss: 2.306795  [ 6400/60000]
# loss: 2.312776  [12800/60000]
# loss: 2.304621  [19200/60000]
# loss: 2.281354  [25600/60000]
# loss: 2.304950  [32000/60000]
# loss: 2.305916  [38400/60000]
# loss: 2.288610  [44800/60000]
# loss: 2.300421  [51200/60000]
# loss: 2.330204  [57600/60000]
# Average Train loss: 2.306093
# Test Error:
#  Accuracy: 10.0%, Avg loss: 2.305833
#
# Epoch 8
# ------------------------------
# loss: 2.312982  [    0/60000]
# loss: 2.306795  [ 6400/60000]
# loss: 2.312776  [12800/60000]
# loss: 2.304621  [19200/60000]
# loss: 2.281345  [25600/60000]
# loss: 2.304950  [32000/60000]
# loss: 2.305910  [38400/60000]
# loss: 2.288610  [44800/60000]
# loss: 2.300421  [51200/60000]
# loss: 2.330204  [57600/60000]
# Average Train loss: 2.306070
# Test Error:
#  Accuracy: 10.0%, Avg loss: 2.305787
#
# Epoch 9
# ------------------------------
# loss: 2.312830  [    0/60000]
# loss: 2.306795  [ 6400/60000]
# loss: 2.312771  [12800/60000]
# loss: 2.306372  [19200/60000]
# loss: 2.281333  [25600/60000]
# loss: 2.304950  [32000/60000]
# loss: 2.305888  [38400/60000]
# loss: 2.288610  [44800/60000]
# loss: 2.300421  [51200/60000]
# loss: 2.330204  [57600/60000]
# Average Train loss: 2.305785
# Test Error:
#  Accuracy: 10.0%, Avg loss: 2.305758
#
# Epoch 10
# ------------------------------
# loss: 2.312786  [    0/60000]
# loss: 2.306538  [ 6400/60000]
# loss: 2.312749  [12800/60000]
# loss: 2.304662  [19200/60000]
# loss: 2.281357  [25600/60000]
# loss: 2.304950  [32000/60000]
# loss: 2.305858  [38400/60000]
# loss: 2.288610  [44800/60000]
# loss: 2.300421  [51200/60000]
# loss: 2.330204  [57600/60000]
# Average Train loss: 2.306183
# Test Error:
#  Accuracy: 10.0%, Avg loss: 2.305082
#
# Accuracy after 10 epochs: 0.1
# Finish running!
# Training with learning rate: 0.1
# Learning rate: 0.1
# ------------------------------
# Epoch 1
# ------------------------------
# loss: 2.298730  [    0/60000]
# loss: 0.908623  [ 6400/60000]
# loss: 0.580196  [12800/60000]
# loss: 0.720629  [19200/60000]
# loss: 0.614350  [25600/60000]
# loss: 0.500302  [32000/60000]
# loss: 0.540581  [38400/60000]
# loss: 0.599433  [44800/60000]
# loss: 0.616562  [51200/60000]
# loss: 0.458594  [57600/60000]
# Average Train loss: 0.654657
# Test Error:
#  Accuracy: 78.1%, Avg loss: 0.571193
#
# Epoch 2
# ------------------------------
# loss: 0.465054  [    0/60000]
# loss: 0.442642  [ 6400/60000]
# loss: 0.377082  [12800/60000]
# loss: 0.440151  [19200/60000]
# loss: 0.403445  [25600/60000]
# loss: 0.436655  [32000/60000]
# loss: 0.406358  [38400/60000]
# loss: 0.507337  [44800/60000]
# loss: 0.526519  [51200/60000]
# loss: 0.432994  [57600/60000]
# Average Train loss: 0.424438
# Test Error:
#  Accuracy: 81.3%, Avg loss: 0.488511
#
# Epoch 3
# ------------------------------
# loss: 0.358920  [    0/60000]
# loss: 0.366159  [ 6400/60000]
# loss: 0.310650  [12800/60000]
# loss: 0.365913  [19200/60000]
# loss: 0.336239  [25600/60000]
# loss: 0.408728  [32000/60000]
# loss: 0.349020  [38400/60000]
# loss: 0.467654  [44800/60000]
# loss: 0.465646  [51200/60000]
# loss: 0.415533  [57600/60000]
# Average Train loss: 0.375505
# Test Error:
#  Accuracy: 83.2%, Avg loss: 0.446801
#
# Epoch 4
# ------------------------------
# loss: 0.290721  [    0/60000]
# loss: 0.334928  [ 6400/60000]
# loss: 0.265934  [12800/60000]
# loss: 0.319810  [19200/60000]
# loss: 0.319318  [25600/60000]
# loss: 0.390072  [32000/60000]
# loss: 0.320641  [38400/60000]
# loss: 0.418341  [44800/60000]
# loss: 0.431594  [51200/60000]
# loss: 0.401941  [57600/60000]
# Average Train loss: 0.344942
# Test Error:
#  Accuracy: 84.4%, Avg loss: 0.415021
#
# Epoch 5
# ------------------------------
# loss: 0.251623  [    0/60000]
# loss: 0.310359  [ 6400/60000]
# loss: 0.229984  [12800/60000]
# loss: 0.302930  [19200/60000]
# loss: 0.300974  [25600/60000]
# loss: 0.375038  [32000/60000]
# loss: 0.295272  [38400/60000]
# loss: 0.381145  [44800/60000]
# loss: 0.404316  [51200/60000]
# loss: 0.380406  [57600/60000]
# Average Train loss: 0.322477
# Test Error:
#  Accuracy: 85.7%, Avg loss: 0.389594
#
# Epoch 6
# ------------------------------
# loss: 0.223772  [    0/60000]
# loss: 0.287521  [ 6400/60000]
# loss: 0.215778  [12800/60000]
# loss: 0.271372  [19200/60000]
# loss: 0.289058  [25600/60000]
# loss: 0.365862  [32000/60000]
# loss: 0.280939  [38400/60000]
# loss: 0.363203  [44800/60000]
# loss: 0.384423  [51200/60000]
# loss: 0.368786  [57600/60000]
# Average Train loss: 0.304477
# Test Error:
#  Accuracy: 86.0%, Avg loss: 0.371941
#
# Epoch 7
# ------------------------------
# loss: 0.213792  [    0/60000]
# loss: 0.273293  [ 6400/60000]
# loss: 0.195239  [12800/60000]
# loss: 0.252823  [19200/60000]
# loss: 0.280653  [25600/60000]
# loss: 0.348211  [32000/60000]
# loss: 0.256258  [38400/60000]
# loss: 0.328084  [44800/60000]
# loss: 0.371048  [51200/60000]
# loss: 0.348812  [57600/60000]
# Average Train loss: 0.289304
# Test Error:
#  Accuracy: 86.6%, Avg loss: 0.362419
#
# Epoch 8
# ------------------------------
# loss: 0.203672  [    0/60000]
# loss: 0.258862  [ 6400/60000]
# loss: 0.187886  [12800/60000]
# loss: 0.241832  [19200/60000]
# loss: 0.277331  [25600/60000]
# loss: 0.337186  [32000/60000]
# loss: 0.243633  [38400/60000]
# loss: 0.309428  [44800/60000]
# loss: 0.347340  [51200/60000]
# loss: 0.343401  [57600/60000]
# Average Train loss: 0.275754
# Test Error:
#  Accuracy: 87.1%, Avg loss: 0.355105
#
# Epoch 9
# ------------------------------
# loss: 0.190051  [    0/60000]
# loss: 0.250311  [ 6400/60000]
# loss: 0.179111  [12800/60000]
# loss: 0.227047  [19200/60000]
# loss: 0.265265  [25600/60000]
# loss: 0.324286  [32000/60000]
# loss: 0.235161  [38400/60000]
# loss: 0.303972  [44800/60000]
# loss: 0.339473  [51200/60000]
# loss: 0.336972  [57600/60000]
# Average Train loss: 0.263608
# Test Error:
#  Accuracy: 87.3%, Avg loss: 0.350590
#
# Epoch 10
# ------------------------------
# loss: 0.182916  [    0/60000]
# loss: 0.235876  [ 6400/60000]
# loss: 0.168496  [12800/60000]
# loss: 0.221832  [19200/60000]
# loss: 0.257252  [25600/60000]
# loss: 0.307938  [32000/60000]
# loss: 0.216700  [38400/60000]
# loss: 0.296519  [44800/60000]
# loss: 0.311959  [51200/60000]
# loss: 0.313996  [57600/60000]
# Average Train loss: 0.252720
# Test Error:
#  Accuracy: 87.8%, Avg loss: 0.341121
#
# Accuracy after 10 epochs: 0.8778
# Finish running!
# Training with learning rate: 0.01
# Learning rate: 0.01
# ------------------------------
# Epoch 1
# ------------------------------
# loss: 2.298730  [    0/60000]
# loss: 2.178367  [ 6400/60000]
# loss: 1.849754  [12800/60000]
# loss: 1.528751  [19200/60000]
# loss: 1.139649  [25600/60000]
# loss: 1.045532  [32000/60000]
# loss: 1.001960  [38400/60000]
# loss: 0.867484  [44800/60000]
# loss: 0.878235  [51200/60000]
# loss: 0.814645  [57600/60000]
# Average Train loss: 1.305030
# Test Error:
#  Accuracy: 71.4%, Avg loss: 0.793621
#
# Epoch 2
# ------------------------------
# loss: 0.801767  [    0/60000]
# loss: 0.855762  [ 6400/60000]
# loss: 0.581759  [12800/60000]
# loss: 0.788707  [19200/60000]
# loss: 0.652793  [25600/60000]
# loss: 0.635075  [32000/60000]
# loss: 0.703701  [38400/60000]
# loss: 0.674424  [44800/60000]
# loss: 0.711521  [51200/60000]
# loss: 0.647212  [57600/60000]
# Average Train loss: 0.683126
# Test Error:
#  Accuracy: 78.0%, Avg loss: 0.635888
#
# Epoch 3
# ------------------------------
# loss: 0.573724  [    0/60000]
# loss: 0.664941  [ 6400/60000]
# loss: 0.438606  [12800/60000]
# loss: 0.676197  [19200/60000]
# loss: 0.573405  [25600/60000]
# loss: 0.558118  [32000/60000]
# loss: 0.587783  [38400/60000]
# loss: 0.629465  [44800/60000]
# loss: 0.676521  [51200/60000]
# loss: 0.556131  [57600/60000]
# Average Train loss: 0.572993
# Test Error:
#  Accuracy: 79.8%, Avg loss: 0.572588
#
# Epoch 4
# ------------------------------
# loss: 0.481805  [    0/60000]
# loss: 0.579509  [ 6400/60000]
# loss: 0.381160  [12800/60000]
# loss: 0.608262  [19200/60000]
# loss: 0.515725  [25600/60000]
# loss: 0.515945  [32000/60000]
# loss: 0.534222  [38400/60000]
# loss: 0.632622  [44800/60000]
# loss: 0.657791  [51200/60000]
# loss: 0.489830  [57600/60000]
# Average Train loss: 0.518312
# Test Error:
#  Accuracy: 80.6%, Avg loss: 0.540414
#
# Epoch 5
# ------------------------------
# loss: 0.426458  [    0/60000]
# loss: 0.534343  [ 6400/60000]
# loss: 0.349507  [12800/60000]
# loss: 0.563235  [19200/60000]
# loss: 0.473009  [25600/60000]
# loss: 0.486000  [32000/60000]
# loss: 0.503971  [38400/60000]
# loss: 0.634473  [44800/60000]
# loss: 0.636678  [51200/60000]
# loss: 0.449335  [57600/60000]
# Average Train loss: 0.486933
# Test Error:
#  Accuracy: 81.2%, Avg loss: 0.520421
#
# Epoch 6
# ------------------------------
# loss: 0.385717  [    0/60000]
# loss: 0.507188  [ 6400/60000]
# loss: 0.328482  [12800/60000]
# loss: 0.533303  [19200/60000]
# loss: 0.444364  [25600/60000]
# loss: 0.465373  [32000/60000]
# loss: 0.482541  [38400/60000]
# loss: 0.626935  [44800/60000]
# loss: 0.616673  [51200/60000]
# loss: 0.427897  [57600/60000]
# Average Train loss: 0.466258
# Test Error:
#  Accuracy: 81.6%, Avg loss: 0.504930
#
# Epoch 7
# ------------------------------
# loss: 0.353502  [    0/60000]
# loss: 0.486779  [ 6400/60000]
# loss: 0.312819  [12800/60000]
# loss: 0.512649  [19200/60000]
# loss: 0.422488  [25600/60000]
# loss: 0.450816  [32000/60000]
# loss: 0.465795  [38400/60000]
# loss: 0.614176  [44800/60000]
# loss: 0.598966  [51200/60000]
# loss: 0.415600  [57600/60000]
# Average Train loss: 0.450716
# Test Error:
#  Accuracy: 82.2%, Avg loss: 0.493707
#
# Epoch 8
# ------------------------------
# loss: 0.329627  [    0/60000]
# loss: 0.468709  [ 6400/60000]
# loss: 0.300897  [12800/60000]
# loss: 0.496739  [19200/60000]
# loss: 0.404375  [25600/60000]
# loss: 0.439918  [32000/60000]
# loss: 0.452215  [38400/60000]
# loss: 0.599528  [44800/60000]
# loss: 0.582419  [51200/60000]
# loss: 0.406714  [57600/60000]
# Average Train loss: 0.438010
# Test Error:
#  Accuracy: 82.6%, Avg loss: 0.483072
#
# Epoch 9
# ------------------------------
# loss: 0.309972  [    0/60000]
# loss: 0.453946  [ 6400/60000]
# loss: 0.291049  [12800/60000]
# loss: 0.484356  [19200/60000]
# loss: 0.387277  [25600/60000]
# loss: 0.431240  [32000/60000]
# loss: 0.439151  [38400/60000]
# loss: 0.586903  [44800/60000]
# loss: 0.568350  [51200/60000]
# loss: 0.400040  [57600/60000]
# Average Train loss: 0.427060
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.473600
#
# Epoch 10
# ------------------------------
# loss: 0.295995  [    0/60000]
# loss: 0.440301  [ 6400/60000]
# loss: 0.282777  [12800/60000]
# loss: 0.473213  [19200/60000]
# loss: 0.372501  [25600/60000]
# loss: 0.423184  [32000/60000]
# loss: 0.427808  [38400/60000]
# loss: 0.575227  [44800/60000]
# loss: 0.554983  [51200/60000]
# loss: 0.395063  [57600/60000]
# Average Train loss: 0.417348
# Test Error:
#  Accuracy: 83.2%, Avg loss: 0.464337
#
# Accuracy after 10 epochs: 0.8317
# Finish running!
# Training with learning rate: 0.001
# Learning rate: 0.001
# ------------------------------
# Epoch 1
# ------------------------------
# loss: 2.298730  [    0/60000]
# loss: 2.289123  [ 6400/60000]
# loss: 2.273286  [12800/60000]
# loss: 2.269406  [19200/60000]
# loss: 2.249603  [25600/60000]
# loss: 2.229407  [32000/60000]
# loss: 2.227369  [38400/60000]
# loss: 2.204261  [44800/60000]
# loss: 2.206194  [51200/60000]
# loss: 2.166653  [57600/60000]
# Average Train loss: 2.237486
# Test Error:
#  Accuracy: 50.9%, Avg loss: 2.166725
#
# Epoch 2
# ------------------------------
# loss: 2.176751  [    0/60000]
# loss: 2.169596  [ 6400/60000]
# loss: 2.117501  [12800/60000]
# loss: 2.129274  [19200/60000]
# loss: 2.079674  [25600/60000]
# loss: 2.032929  [32000/60000]
# loss: 2.050117  [38400/60000]
# loss: 1.985240  [44800/60000]
# loss: 1.987890  [51200/60000]
# loss: 1.907166  [57600/60000]
# Average Train loss: 2.053737
# Test Error:
#  Accuracy: 55.9%, Avg loss: 1.915489
#
# Epoch 3
# ------------------------------
# loss: 1.951617  [    0/60000]
# loss: 1.928689  [ 6400/60000]
# loss: 1.815715  [12800/60000]
# loss: 1.841556  [19200/60000]
# loss: 1.732472  [25600/60000]
# loss: 1.692918  [32000/60000]
# loss: 1.701719  [38400/60000]
# loss: 1.610639  [44800/60000]
# loss: 1.632874  [51200/60000]
# loss: 1.514268  [57600/60000]
# Average Train loss: 1.725203
# Test Error:
#  Accuracy: 58.8%, Avg loss: 1.541530
#
# Epoch 4
# ------------------------------
# loss: 1.616452  [    0/60000]
# loss: 1.582895  [ 6400/60000]
# loss: 1.427598  [12800/60000]
# loss: 1.487957  [19200/60000]
# loss: 1.359335  [25600/60000]
# loss: 1.364819  [32000/60000]
# loss: 1.371494  [38400/60000]
# loss: 1.298711  [44800/60000]
# loss: 1.336203  [51200/60000]
# loss: 1.232148  [57600/60000]
# Average Train loss: 1.382757
# Test Error:
#  Accuracy: 62.2%, Avg loss: 1.260240
#
# Epoch 5
# ------------------------------
# loss: 1.345540  [    0/60000]
# loss: 1.327800  [ 6400/60000]
# loss: 1.153804  [12800/60000]
# loss: 1.254833  [19200/60000]
# loss: 1.117322  [25600/60000]
# loss: 1.153251  [32000/60000]
# loss: 1.171767  [38400/60000]
# loss: 1.110265  [44800/60000]
# loss: 1.154469  [51200/60000]
# loss: 1.070923  [57600/60000]
# Average Train loss: 1.158959
# Test Error:
#  Accuracy: 64.1%, Avg loss: 1.089833
#
# Epoch 6
# ------------------------------
# loss: 1.166889  [    0/60000]
# loss: 1.170518  [ 6400/60000]
# loss: 0.979437  [12800/60000]
# loss: 1.113775  [19200/60000]
# loss: 0.973409  [25600/60000]
# loss: 1.015193  [32000/60000]
# loss: 1.051112  [38400/60000]
# loss: 0.993593  [44800/60000]
# loss: 1.039709  [51200/60000]
# loss: 0.971079  [57600/60000]
# Average Train loss: 1.021277
# Test Error:
#  Accuracy: 65.8%, Avg loss: 0.982441
#
# Epoch 7
# ------------------------------
# loss: 1.045164  [    0/60000]
# loss: 1.070585  [ 6400/60000]
# loss: 0.862306  [12800/60000]
# loss: 1.022268  [19200/60000]
# loss: 0.885212  [25600/60000]
# loss: 0.919528  [32000/60000]
# loss: 0.972762  [38400/60000]
# loss: 0.918731  [44800/60000]
# loss: 0.961629  [51200/60000]
# loss: 0.904377  [57600/60000]
# Average Train loss: 0.931515
# Test Error:
#  Accuracy: 66.9%, Avg loss: 0.910168
#
# Epoch 8
# ------------------------------
# loss: 0.956962  [    0/60000]
# loss: 1.002173  [ 6400/60000]
# loss: 0.779055  [12800/60000]
# loss: 0.958412  [19200/60000]
# loss: 0.827239  [25600/60000]
# loss: 0.850260  [32000/60000]
# loss: 0.917318  [38400/60000]
# loss: 0.868385  [44800/60000]
# loss: 0.905504  [51200/60000]
# loss: 0.856356  [57600/60000]
# Average Train loss: 0.868992
# Test Error:
#  Accuracy: 68.3%, Avg loss: 0.858248
#
# Epoch 9
# ------------------------------
# loss: 0.889764  [    0/60000]
# loss: 0.951219  [ 6400/60000]
# loss: 0.717035  [12800/60000]
# loss: 0.911043  [19200/60000]
# loss: 0.786088  [25600/60000]
# loss: 0.798370  [32000/60000]
# loss: 0.874937  [38400/60000]
# loss: 0.832794  [44800/60000]
# loss: 0.863252  [51200/60000]
# loss: 0.819741  [57600/60000]
# Average Train loss: 0.822722
# Test Error:
#  Accuracy: 69.5%, Avg loss: 0.818779
#
# Epoch 10
# ------------------------------
# loss: 0.836396  [    0/60000]
# loss: 0.910216  [ 6400/60000]
# loss: 0.668507  [12800/60000]
# loss: 0.874334  [19200/60000]
# loss: 0.754803  [25600/60000]
# loss: 0.758450  [32000/60000]
# loss: 0.840448  [38400/60000]
# loss: 0.806152  [44800/60000]
# loss: 0.830361  [51200/60000]
# loss: 0.790279  [57600/60000]
# Average Train loss: 0.786659
# Test Error:
#  Accuracy: 71.0%, Avg loss: 0.787270
#
# Accuracy after 10 epochs: 0.7095
# Finish running!

# %%
# Get the accuracy for reporting
for lr in learning_rates:
    print(f"Learning rate {lr} - Accuracy after 10 epochs: {(results[lr]['accuracy_list'][-1] * 100)}%")
# Out:
# Learning rate 1 - Accuracy after 10 epochs: 10.0%
# Learning rate 0.1 - Accuracy after 10 epochs: 87.78%
# Learning rate 0.01 - Accuracy after 10 epochs: 83.17%
# Learning rate 0.001 - Accuracy after 10 epochs: 70.95%

# %%
# Plot training loss for different learning rates
plt.figure(figsize=(20, 14))
for lr in learning_rates:
    train_losses = results[lr]['train_losses']
    plt.plot(range(1, len(train_losses) + 1), train_losses, label=f'Training Loss (lr={lr})')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training Loss in model using Different Learning Rates')
plt.legend()
plt.show()

# Plot test loss for different learning rates
plt.figure(figsize=(20, 14))
for lr in learning_rates:
    test_losses = results[lr]['test_losses']
    plt.plot(range(1, len(test_losses) + 1), test_losses, label=f'Test Loss (lr={lr})')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Test Loss in model using Different Learning Rates')
plt.legend()
plt.show()

# Plot accuracy for different learning rates
plt.figure(figsize=(20, 14))
for lr in learning_rates:
    accuracies = results[lr]['accuracy_list']
    plt.plot(range(1, len(accuracies) + 1), accuracies, label=f'Accuracy (lr={lr})')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Accuracy for model using Different Learning Rates')
plt.legend()
plt.show()

# %% [markdown]
# **Analysis of the Plots:**
#
# **1. Training Loss Plot**
#
# *LR = 1:* The training loss exhibits instability, especially around epoch 5 where it spikes dramatically. This indicates that the model with LR=1 is not converging properly and is likely oscillating or diverging.
#
# *LR = 0.1:* The training loss decreases steadily, showing a smooth and consistent decline.
#
# *LR = 0.01:* The training loss also decreases steadily but at a slower rate compared to LR = 0.1.
#
# *LR = 0.001:* The training loss decreases very slowly, indicating slow learning.
#
# **2. Test Loss Plot**
#
# *LR = 1:* The test loss is high and inconsistent, reinforcing that LR = 1 is too high for stable learning.
#
# *LR = 0.1:* The test loss decreases steadily and reaches a lower value compared to other learning rates, indicating good generalization.
#
# *LR = 0.01:* The test loss decreases steadily but is slightly higher than LR = 0.1.
#
# *LR = 0.001:* The test loss decreases slowly, similar to the training loss, indicating slow convergence.
#
# **3. Accuracy Plot**
#
# *LR = 1:* The accuracy is low and fluctuates, failing to improve meaningfully.
#
# *LR = 0.1:* The accuracy improves consistently and reaches the highest value among the tested learning rates.
#
# *LR = 0.01:* The accuracy also improves consistently but to a slightly lesser extent compared to LR = 0.1.
#
# *LR = 0.001:* The accuracy improves but at a slower rate and does not reach as high as the other learning rates within the same number of epochs.

# %% [markdown]
# Run the training code for 10 epochs, for different values of the learning rate. The results of each learning rates experiments are as follows:
#
# |Lr|Accuracy|
# |---|---|
# |1   |  10%    |
# |0.1|    87.78%      |
# |0.01|   83.17%      ||
# |0.001  |   70.95%     |

# %% [markdown]
# **Result analysis**
#
# ***Training with Learning Rate: 1***
#
# - Train Loss: Initially, the train loss decreases, but it increases drastically in later epochs.
#
# - Test Loss: The test loss is high and does not show consistent improvement.
#
# - Accuracy: Starts low and remains low, around *10%*, which is no better than random guessing.
#
# Explanation: A learning rate of 1 is too high, causing the model to overshoot the optimal weights during training. This results in a failure to converge, leading to poor performance.
#
# ***Training with Learning Rate: 0.1***
#
# - Train Loss: The train loss decreases steadily over epochs.
#
# - Test Loss: The test loss also decreases, indicating good generalization.
#
# - Accuracy: The accuracy improves consistently, reaching around *87.8%* after 10 epochs.
#
# Explanation: A learning rate of 0.1 appears to be well-suited for this model and dataset, allowing the network to converge to a good solution efficiently.
#
# ***Training with Learning Rate: 0.01***
#
# - Train Loss: The train loss decreases steadily but at a slower rate compared to LR = 0.1.
#
# - Test Loss: The test loss also decreases but remains slightly higher than the results with LR = 0.1.
#
# - Accuracy: The accuracy improves to around **83.2%** after 10 epochs.
#
# Explanation: A learning rate of 0.01 is also effective, but the convergence is slower, and the final performance is slightly lower compared to LR = 0.1.
#
# ***Training with Learning Rate: 0.001***
#
# - Train Loss: The train loss decreases steadily but very slowly.
#
# - Test Loss: The test loss also decreases but at a slow rate.
#
# - Accuracy: The accuracy improves but reaches only about 71% after 10 epochs.
#
# Explanation: A learning rate of 0.001 is too low, leading to very slow convergence. Although the model is learning, it is not able to achieve as high performance within the same number of epochs as with higher learning rates.
#
# ***Conclusions***
#
# - Learning Rate 1: Too high, leads to non-convergence and poor performance.
#
# - Learning Rate 0.1: Optimal, provides the best convergence speed and highest accuracy.
#
# - Learning Rate 0.01: Good but slower convergence and slightly lower final accuracy.
#
# - Learning Rate 0.001: Too low, leading to slow convergence and suboptimal performance within 10 epochs.

# %% [markdown]
# **Q1.3 (3 points)**
#
# Report the number of epochs when the accuracy reaches 85%. Fill in the table below and plot the loass curve for each experiment:
#
# |Lr|Accuracy|Epoch|
# |---|---|---|
# |1   |      |     |
# |0.1|          |    |
# |0.01|         |    |
# |0.001  |        |     |

# %%
def reaching_train_test_85(lr, patience=5, max_epochs=60):
    # Set the default random seed 42
    set_seed(42)

    print(f'Learning rate: {lr}\n{'-' * 30}')

    # Initialize variables
    train_losses = []
    test_losses = []
    accuracy_list = []

    best_epoch = 0
    
    # Initialize model and optimizer
    model = NeuralNetwork().to(device)
    optimizer = torch.optim.SGD(model.parameters(), lr=lr)

    t = 1
    best_accuracy = 0
    epochs_no_improve = 0

    while t <= max_epochs:
        print(f"Epoch {t+1}\n{'-' * 30}")

        train_loss = train(train_dataloader, model, loss_fn, optimizer)
        test_loss, correct = test(test_dataloader, model, loss_fn)

        train_losses.append(train_loss)
        test_losses.append(test_loss)
        accuracy_list.append(correct)

        if correct > best_accuracy:
            best_accuracy = correct
            best_epoch = t
            epochs_no_improve = 0
        else:
            epochs_no_improve += 1

        if correct >= 0.85:
            print(f"Accuracy reached 85% after {t} epochs: {correct:>5f}")
            break

        if epochs_no_improve >= patience:
            print(f"Early stopping after {t} epochs: no improvement for {patience} epochs")
            break

        t += 1

    if correct < 0.85:
        print(f"Stopped after {t-1} epochs without reaching 85% accuracy. Best accuracy: {best_accuracy:>6f}")

    print("Done!")

    return train_losses, test_losses, accuracy_list, best_epoch, best_accuracy

# %%
# Test different learning rate and save the result
learning_rates = [1, 0.1, 0.01, 0.001]
result_to_85 = {}

for lr in learning_rates:
    print(f"Training with learning rate: {lr}")
    train_losses, test_losses, accuracy_list, best_epoch, best_accuracy  = reaching_train_test_85(lr)
    result_to_85[lr] = {
        'train_losses': train_losses,
        'test_losses': test_losses,
        'accuracy_list': accuracy_list,
        'best_epoch': best_epoch,
        'best_accuracy': best_accuracy
        
    }
# Out:
# Training with learning rate: 1
# Learning rate: 1
# ------------------------------
# Epoch 2
# ------------------------------
# loss: 2.298730  [    0/60000]
# loss: 2.078346  [ 6400/60000]
# loss: 2.063327  [12800/60000]
# loss: 1.884854  [19200/60000]
# loss: 1.656733  [25600/60000]
# loss: 1.679165  [32000/60000]
# loss: 1.421637  [38400/60000]
# loss: 1.532273  [44800/60000]
# loss: 1.777356  [51200/60000]
# loss: 1.685938  [57600/60000]
# Average Train loss: 1.880750
# Test Error:
#  Accuracy: 20.0%, Avg loss: 1.915828
#
# Epoch 3
# ------------------------------
# loss: 1.966882  [    0/60000]
# loss: 1.915499  [ 6400/60000]
# loss: 1.766465  [12800/60000]
# loss: 1.752323  [19200/60000]
# loss: 1.623561  [25600/60000]
# loss: 1.487857  [32000/60000]
# loss: 1.413146  [38400/60000]
# loss: 1.680380  [44800/60000]
# loss: 1.637021  [51200/60000]
# loss: 1.469961  [57600/60000]
# Average Train loss: 1.699385
# Test Error:
#  Accuracy: 28.6%, Avg loss: 1.493816
#
# Epoch 4
# ------------------------------
# loss: 1.612844  [    0/60000]
# loss: 1.632038  [ 6400/60000]
# loss: 1.441342  [12800/60000]
# loss: 1.812690  [19200/60000]
# loss: 1.686181  [25600/60000]
# loss: 1.731072  [32000/60000]
# loss: 1.489014  [38400/60000]
# loss: 3.103043  [44800/60000]
# loss: 1.750626  [51200/60000]
# loss: 1.516080  [57600/60000]
# Average Train loss: 4.268775
# Test Error:
#  Accuracy: 30.1%, Avg loss: 1.626754
#
# Epoch 5
# ------------------------------
# loss: 1.564310  [    0/60000]
# loss: 1.492587  [ 6400/60000]
# loss: 1.595447  [12800/60000]
# loss: 1.654886  [19200/60000]
# loss: 1.527521  [25600/60000]
# loss: 2.173019  [32000/60000]
# loss: 1.356197  [38400/60000]
# loss: 1.455516  [44800/60000]
# loss: 1.712601  [51200/60000]
# loss: 1.722220  [57600/60000]
# Average Train loss: 1.694534
# Test Error:
#  Accuracy: 19.8%, Avg loss: 1.747444
#
# Epoch 6
# ------------------------------
# loss: 1.787047  [    0/60000]
# loss: 2.313029  [ 6400/60000]
# loss: 1.856514  [12800/60000]
# loss: 2.268281  [19200/60000]
# loss: 2.265279  [25600/60000]
# loss: 2.125515  [32000/60000]
# loss: 2.295030  [38400/60000]
# loss: 1.759692  [44800/60000]
# loss: 2.272519  [51200/60000]
# loss: 1.574183  [57600/60000]
# Average Train loss: 155.936189
# Test Error:
#  Accuracy: 10.1%, Avg loss: 2.309788
#
# Epoch 7
# ------------------------------
# loss: 2.314454  [    0/60000]
# loss: 2.314639  [ 6400/60000]
# loss: 2.350553  [12800/60000]
# loss: 2.509769  [19200/60000]
# loss: 1.626091  [25600/60000]
# loss: 1.773114  [32000/60000]
# loss: 2.303272  [38400/60000]
# loss: 2.288610  [44800/60000]
# loss: 2.300421  [51200/60000]
# loss: 2.330204  [57600/60000]
# Average Train loss: 2.270584
# Test Error:
#  Accuracy: 10.0%, Avg loss: 2.305845
#
# Epoch 8
# ------------------------------
# loss: 2.313043  [    0/60000]
# loss: 2.306795  [ 6400/60000]
# loss: 2.312776  [12800/60000]
# loss: 2.304621  [19200/60000]
# loss: 2.281354  [25600/60000]
# loss: 2.304950  [32000/60000]
# loss: 2.305916  [38400/60000]
# loss: 2.288610  [44800/60000]
# loss: 2.300421  [51200/60000]
# loss: 2.330204  [57600/60000]
# Average Train loss: 2.306093
# Test Error:
#  Accuracy: 10.0%, Avg loss: 2.305833
#
# Epoch 9
# ------------------------------
# loss: 2.312982  [    0/60000]
# loss: 2.306795  [ 6400/60000]
# loss: 2.312776  [12800/60000]
# loss: 2.304621  [19200/60000]
# loss: 2.281345  [25600/60000]
# loss: 2.304950  [32000/60000]
# loss: 2.305910  [38400/60000]
# loss: 2.288610  [44800/60000]
# loss: 2.300421  [51200/60000]
# loss: 2.330204  [57600/60000]
# Average Train loss: 2.306070
# Test Error:
#  Accuracy: 10.0%, Avg loss: 2.305787
#
# Early stopping after 8 epochs: no improvement for 5 epochs
# Stopped after 7 epochs without reaching 85% accuracy. Best accuracy: 0.300800
# Done!
# Training with learning rate: 0.1
# Learning rate: 0.1
# ------------------------------
# Epoch 2
# ------------------------------
# loss: 2.298730  [    0/60000]
# loss: 0.908623  [ 6400/60000]
# loss: 0.580196  [12800/60000]
# loss: 0.720629  [19200/60000]
# loss: 0.614350  [25600/60000]
# loss: 0.500302  [32000/60000]
# loss: 0.540581  [38400/60000]
# loss: 0.599433  [44800/60000]
# loss: 0.616562  [51200/60000]
# loss: 0.458594  [57600/60000]
# Average Train loss: 0.654657
# Test Error:
#  Accuracy: 78.1%, Avg loss: 0.571193
#
# Epoch 3
# ------------------------------
# loss: 0.465054  [    0/60000]
# loss: 0.442642  [ 6400/60000]
# loss: 0.377082  [12800/60000]
# loss: 0.440151  [19200/60000]
# loss: 0.403445  [25600/60000]
# loss: 0.436655  [32000/60000]
# loss: 0.406358  [38400/60000]
# loss: 0.507337  [44800/60000]
# loss: 0.526519  [51200/60000]
# loss: 0.432994  [57600/60000]
# Average Train loss: 0.424438
# Test Error:
#  Accuracy: 81.3%, Avg loss: 0.488511
#
# Epoch 4
# ------------------------------
# loss: 0.358920  [    0/60000]
# loss: 0.366159  [ 6400/60000]
# loss: 0.310650  [12800/60000]
# loss: 0.365913  [19200/60000]
# loss: 0.336239  [25600/60000]
# loss: 0.408728  [32000/60000]
# loss: 0.349020  [38400/60000]
# loss: 0.467654  [44800/60000]
# loss: 0.465646  [51200/60000]
# loss: 0.415533  [57600/60000]
# Average Train loss: 0.375505
# Test Error:
#  Accuracy: 83.2%, Avg loss: 0.446801
#
# Epoch 5
# ------------------------------
# loss: 0.290721  [    0/60000]
# loss: 0.334928  [ 6400/60000]
# loss: 0.265934  [12800/60000]
# loss: 0.319810  [19200/60000]
# loss: 0.319318  [25600/60000]
# loss: 0.390072  [32000/60000]
# loss: 0.320641  [38400/60000]
# loss: 0.418341  [44800/60000]
# loss: 0.431594  [51200/60000]
# loss: 0.401941  [57600/60000]
# Average Train loss: 0.344942
# Test Error:
#  Accuracy: 84.4%, Avg loss: 0.415021
#
# Epoch 6
# ------------------------------
# loss: 0.251623  [    0/60000]
# loss: 0.310359  [ 6400/60000]
# loss: 0.229984  [12800/60000]
# loss: 0.302930  [19200/60000]
# loss: 0.300974  [25600/60000]
# loss: 0.375038  [32000/60000]
# loss: 0.295272  [38400/60000]
# loss: 0.381145  [44800/60000]
# loss: 0.404316  [51200/60000]
# loss: 0.380406  [57600/60000]
# Average Train loss: 0.322477
# Test Error:
#  Accuracy: 85.7%, Avg loss: 0.389594
#
# Accuracy reached 85% after 5 epochs: 0.857100
# Done!
# Training with learning rate: 0.01
# Learning rate: 0.01
# ------------------------------
# Epoch 2
# ------------------------------
# loss: 2.298730  [    0/60000]
# loss: 2.178367  [ 6400/60000]
# loss: 1.849754  [12800/60000]
# loss: 1.528751  [19200/60000]
# loss: 1.139649  [25600/60000]
# loss: 1.045532  [32000/60000]
# loss: 1.001960  [38400/60000]
# loss: 0.867484  [44800/60000]
# loss: 0.878235  [51200/60000]
# loss: 0.814645  [57600/60000]
# Average Train loss: 1.305030
# Test Error:
#  Accuracy: 71.4%, Avg loss: 0.793621
#
# Epoch 3
# ------------------------------
# loss: 0.801767  [    0/60000]
# loss: 0.855762  [ 6400/60000]
# loss: 0.581759  [12800/60000]
# loss: 0.788707  [19200/60000]
# loss: 0.652793  [25600/60000]
# loss: 0.635075  [32000/60000]
# loss: 0.703701  [38400/60000]
# loss: 0.674424  [44800/60000]
# loss: 0.711521  [51200/60000]
# loss: 0.647212  [57600/60000]
# Average Train loss: 0.683126
# Test Error:
#  Accuracy: 78.0%, Avg loss: 0.635888
#
# Epoch 4
# ------------------------------
# loss: 0.573724  [    0/60000]
# loss: 0.664941  [ 6400/60000]
# loss: 0.438606  [12800/60000]
# loss: 0.676197  [19200/60000]
# loss: 0.573405  [25600/60000]
# loss: 0.558118  [32000/60000]
# loss: 0.587783  [38400/60000]
# loss: 0.629465  [44800/60000]
# loss: 0.676521  [51200/60000]
# loss: 0.556131  [57600/60000]
# Average Train loss: 0.572993
# Test Error:
#  Accuracy: 79.8%, Avg loss: 0.572588
#
# Epoch 5
# ------------------------------
# loss: 0.481805  [    0/60000]
# loss: 0.579509  [ 6400/60000]
# loss: 0.381160  [12800/60000]
# loss: 0.608262  [19200/60000]
# loss: 0.515725  [25600/60000]
# loss: 0.515945  [32000/60000]
# loss: 0.534222  [38400/60000]
# loss: 0.632622  [44800/60000]
# loss: 0.657791  [51200/60000]
# loss: 0.489830  [57600/60000]
# Average Train loss: 0.518312
# Test Error:
#  Accuracy: 80.6%, Avg loss: 0.540414
#
# Epoch 6
# ------------------------------
# loss: 0.426458  [    0/60000]
# loss: 0.534343  [ 6400/60000]
# loss: 0.349507  [12800/60000]
# loss: 0.563235  [19200/60000]
# loss: 0.473009  [25600/60000]
# loss: 0.486000  [32000/60000]
# loss: 0.503971  [38400/60000]
# loss: 0.634473  [44800/60000]
# loss: 0.636678  [51200/60000]
# loss: 0.449335  [57600/60000]
# Average Train loss: 0.486933
# Test Error:
#  Accuracy: 81.2%, Avg loss: 0.520421
#
# Epoch 7
# ------------------------------
# loss: 0.385717  [    0/60000]
# loss: 0.507188  [ 6400/60000]
# loss: 0.328482  [12800/60000]
# loss: 0.533303  [19200/60000]
# loss: 0.444364  [25600/60000]
# loss: 0.465373  [32000/60000]
# loss: 0.482541  [38400/60000]
# loss: 0.626935  [44800/60000]
# loss: 0.616673  [51200/60000]
# loss: 0.427897  [57600/60000]
# Average Train loss: 0.466258
# Test Error:
#  Accuracy: 81.6%, Avg loss: 0.504930
#
# Epoch 8
# ------------------------------
# loss: 0.353502  [    0/60000]
# loss: 0.486779  [ 6400/60000]
# loss: 0.312819  [12800/60000]
# loss: 0.512649  [19200/60000]
# loss: 0.422488  [25600/60000]
# loss: 0.450816  [32000/60000]
# loss: 0.465795  [38400/60000]
# loss: 0.614176  [44800/60000]
# loss: 0.598966  [51200/60000]
# loss: 0.415600  [57600/60000]
# Average Train loss: 0.450716
# Test Error:
#  Accuracy: 82.2%, Avg loss: 0.493707
#
# Epoch 9
# ------------------------------
# loss: 0.329627  [    0/60000]
# loss: 0.468709  [ 6400/60000]
# loss: 0.300897  [12800/60000]
# loss: 0.496739  [19200/60000]
# loss: 0.404375  [25600/60000]
# loss: 0.439918  [32000/60000]
# loss: 0.452215  [38400/60000]
# loss: 0.599528  [44800/60000]
# loss: 0.582419  [51200/60000]
# loss: 0.406714  [57600/60000]
# Average Train loss: 0.438010
# Test Error:
#  Accuracy: 82.6%, Avg loss: 0.483072
#
# Epoch 10
# ------------------------------
# loss: 0.309972  [    0/60000]
# loss: 0.453946  [ 6400/60000]
# loss: 0.291049  [12800/60000]
# loss: 0.484356  [19200/60000]
# loss: 0.387277  [25600/60000]
# loss: 0.431240  [32000/60000]
# loss: 0.439151  [38400/60000]
# loss: 0.586903  [44800/60000]
# loss: 0.568350  [51200/60000]
# loss: 0.400040  [57600/60000]
# Average Train loss: 0.427060
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.473600
#
# Epoch 11
# ------------------------------
# loss: 0.295995  [    0/60000]
# loss: 0.440301  [ 6400/60000]
# loss: 0.282777  [12800/60000]
# loss: 0.473213  [19200/60000]
# loss: 0.372501  [25600/60000]
# loss: 0.423184  [32000/60000]
# loss: 0.427808  [38400/60000]
# loss: 0.575227  [44800/60000]
# loss: 0.554983  [51200/60000]
# loss: 0.395063  [57600/60000]
# Average Train loss: 0.417348
# Test Error:
#  Accuracy: 83.2%, Avg loss: 0.464337
#
# Epoch 12
# ------------------------------
# loss: 0.284832  [    0/60000]
# loss: 0.428145  [ 6400/60000]
# loss: 0.275190  [12800/60000]
# loss: 0.463519  [19200/60000]
# loss: 0.360425  [25600/60000]
# loss: 0.415541  [32000/60000]
# loss: 0.418111  [38400/60000]
# loss: 0.564886  [44800/60000]
# loss: 0.543383  [51200/60000]
# loss: 0.391459  [57600/60000]
# Average Train loss: 0.408603
# Test Error:
#  Accuracy: 83.5%, Avg loss: 0.456443
#
# Epoch 13
# ------------------------------
# loss: 0.276694  [    0/60000]
# loss: 0.417549  [ 6400/60000]
# loss: 0.269370  [12800/60000]
# loss: 0.453938  [19200/60000]
# loss: 0.349291  [25600/60000]
# loss: 0.407824  [32000/60000]
# loss: 0.408956  [38400/60000]
# loss: 0.554710  [44800/60000]
# loss: 0.533140  [51200/60000]
# loss: 0.388160  [57600/60000]
# Average Train loss: 0.400638
# Test Error:
#  Accuracy: 83.8%, Avg loss: 0.449245
#
# Epoch 14
# ------------------------------
# loss: 0.270671  [    0/60000]
# loss: 0.407937  [ 6400/60000]
# loss: 0.263546  [12800/60000]
# loss: 0.445094  [19200/60000]
# loss: 0.340018  [25600/60000]
# loss: 0.400744  [32000/60000]
# loss: 0.400312  [38400/60000]
# loss: 0.545152  [44800/60000]
# loss: 0.522556  [51200/60000]
# loss: 0.384643  [57600/60000]
# Average Train loss: 0.393279
# Test Error:
#  Accuracy: 84.2%, Avg loss: 0.441539
#
# Epoch 15
# ------------------------------
# loss: 0.264725  [    0/60000]
# loss: 0.398585  [ 6400/60000]
# loss: 0.258894  [12800/60000]
# loss: 0.437021  [19200/60000]
# loss: 0.331557  [25600/60000]
# loss: 0.393599  [32000/60000]
# loss: 0.392985  [38400/60000]
# loss: 0.534540  [44800/60000]
# loss: 0.514931  [51200/60000]
# loss: 0.381187  [57600/60000]
# Average Train loss: 0.386330
# Test Error:
#  Accuracy: 84.5%, Avg loss: 0.435158
#
# Epoch 16
# ------------------------------
# loss: 0.260641  [    0/60000]
# loss: 0.389799  [ 6400/60000]
# loss: 0.254197  [12800/60000]
# loss: 0.428931  [19200/60000]
# loss: 0.323313  [25600/60000]
# loss: 0.387385  [32000/60000]
# loss: 0.386657  [38400/60000]
# loss: 0.525540  [44800/60000]
# loss: 0.506999  [51200/60000]
# loss: 0.378666  [57600/60000]
# Average Train loss: 0.379866
# Test Error:
#  Accuracy: 84.7%, Avg loss: 0.428481
#
# Epoch 17
# ------------------------------
# loss: 0.255661  [    0/60000]
# loss: 0.382512  [ 6400/60000]
# loss: 0.249710  [12800/60000]
# loss: 0.420392  [19200/60000]
# loss: 0.316696  [25600/60000]
# loss: 0.380667  [32000/60000]
# loss: 0.380003  [38400/60000]
# loss: 0.515823  [44800/60000]
# loss: 0.498561  [51200/60000]
# loss: 0.377678  [57600/60000]
# Average Train loss: 0.373747
# Test Error:
#  Accuracy: 84.9%, Avg loss: 0.422498
#
# Epoch 18
# ------------------------------
# loss: 0.250844  [    0/60000]
# loss: 0.375876  [ 6400/60000]
# loss: 0.245702  [12800/60000]
# loss: 0.413057  [19200/60000]
# loss: 0.310971  [25600/60000]
# loss: 0.374816  [32000/60000]
# loss: 0.373199  [38400/60000]
# loss: 0.507171  [44800/60000]
# loss: 0.490001  [51200/60000]
# loss: 0.375520  [57600/60000]
# Average Train loss: 0.367902
# Test Error:
#  Accuracy: 85.2%, Avg loss: 0.416608
#
# Accuracy reached 85% after 17 epochs: 0.851900
# Done!
# Training with learning rate: 0.001
# Learning rate: 0.001
# ------------------------------
# Epoch 2
# ------------------------------
# loss: 2.298730  [    0/60000]
# loss: 2.289123  [ 6400/60000]
# loss: 2.273286  [12800/60000]
# loss: 2.269406  [19200/60000]
# loss: 2.249603  [25600/60000]
# loss: 2.229407  [32000/60000]
# loss: 2.227369  [38400/60000]
# loss: 2.204261  [44800/60000]
# loss: 2.206194  [51200/60000]
# loss: 2.166653  [57600/60000]
# Average Train loss: 2.237486
# Test Error:
#  Accuracy: 50.9%, Avg loss: 2.166725
#
# Epoch 3
# ------------------------------
# loss: 2.176751  [    0/60000]
# loss: 2.169596  [ 6400/60000]
# loss: 2.117501  [12800/60000]
# loss: 2.129274  [19200/60000]
# loss: 2.079674  [25600/60000]
# loss: 2.032929  [32000/60000]
# loss: 2.050117  [38400/60000]
# loss: 1.985240  [44800/60000]
# loss: 1.987890  [51200/60000]
# loss: 1.907166  [57600/60000]
# Average Train loss: 2.053737
# Test Error:
#  Accuracy: 55.9%, Avg loss: 1.915489
#
# Epoch 4
# ------------------------------
# loss: 1.951617  [    0/60000]
# loss: 1.928689  [ 6400/60000]
# loss: 1.815715  [12800/60000]
# loss: 1.841556  [19200/60000]
# loss: 1.732472  [25600/60000]
# loss: 1.692918  [32000/60000]
# loss: 1.701719  [38400/60000]
# loss: 1.610639  [44800/60000]
# loss: 1.632874  [51200/60000]
# loss: 1.514268  [57600/60000]
# Average Train loss: 1.725203
# Test Error:
#  Accuracy: 58.8%, Avg loss: 1.541530
#
# Epoch 5
# ------------------------------
# loss: 1.616452  [    0/60000]
# loss: 1.582895  [ 6400/60000]
# loss: 1.427598  [12800/60000]
# loss: 1.487957  [19200/60000]
# loss: 1.359335  [25600/60000]
# loss: 1.364819  [32000/60000]
# loss: 1.371494  [38400/60000]
# loss: 1.298711  [44800/60000]
# loss: 1.336203  [51200/60000]
# loss: 1.232148  [57600/60000]
# Average Train loss: 1.382757
# Test Error:
#  Accuracy: 62.2%, Avg loss: 1.260240
#
# Epoch 6
# ------------------------------
# loss: 1.345540  [    0/60000]
# loss: 1.327800  [ 6400/60000]
# loss: 1.153804  [12800/60000]
# loss: 1.254833  [19200/60000]
# loss: 1.117322  [25600/60000]
# loss: 1.153251  [32000/60000]
# loss: 1.171767  [38400/60000]
# loss: 1.110265  [44800/60000]
# loss: 1.154469  [51200/60000]
# loss: 1.070923  [57600/60000]
# Average Train loss: 1.158959
# Test Error:
#  Accuracy: 64.1%, Avg loss: 1.089833
#
# Epoch 7
# ------------------------------
# loss: 1.166889  [    0/60000]
# loss: 1.170518  [ 6400/60000]
# loss: 0.979437  [12800/60000]
# loss: 1.113775  [19200/60000]
# loss: 0.973409  [25600/60000]
# loss: 1.015193  [32000/60000]
# loss: 1.051112  [38400/60000]
# loss: 0.993593  [44800/60000]
# loss: 1.039709  [51200/60000]
# loss: 0.971079  [57600/60000]
# Average Train loss: 1.021277
# Test Error:
#  Accuracy: 65.8%, Avg loss: 0.982441
#
# Epoch 8
# ------------------------------
# loss: 1.045164  [    0/60000]
# loss: 1.070585  [ 6400/60000]
# loss: 0.862306  [12800/60000]
# loss: 1.022268  [19200/60000]
# loss: 0.885212  [25600/60000]
# loss: 0.919528  [32000/60000]
# loss: 0.972762  [38400/60000]
# loss: 0.918731  [44800/60000]
# loss: 0.961629  [51200/60000]
# loss: 0.904377  [57600/60000]
# Average Train loss: 0.931515
# Test Error:
#  Accuracy: 66.9%, Avg loss: 0.910168
#
# Epoch 9
# ------------------------------
# loss: 0.956962  [    0/60000]
# loss: 1.002173  [ 6400/60000]
# loss: 0.779055  [12800/60000]
# loss: 0.958412  [19200/60000]
# loss: 0.827239  [25600/60000]
# loss: 0.850260  [32000/60000]
# loss: 0.917318  [38400/60000]
# loss: 0.868385  [44800/60000]
# loss: 0.905504  [51200/60000]
# loss: 0.856356  [57600/60000]
# Average Train loss: 0.868992
# Test Error:
#  Accuracy: 68.3%, Avg loss: 0.858248
#
# Epoch 10
# ------------------------------
# loss: 0.889764  [    0/60000]
# loss: 0.951219  [ 6400/60000]
# loss: 0.717035  [12800/60000]
# loss: 0.911043  [19200/60000]
# loss: 0.786088  [25600/60000]
# loss: 0.798370  [32000/60000]
# loss: 0.874937  [38400/60000]
# loss: 0.832794  [44800/60000]
# loss: 0.863252  [51200/60000]
# loss: 0.819741  [57600/60000]
# Average Train loss: 0.822722
# Test Error:
#  Accuracy: 69.5%, Avg loss: 0.818779
#
# Epoch 11
# ------------------------------
# loss: 0.836396  [    0/60000]
# loss: 0.910216  [ 6400/60000]
# loss: 0.668507  [12800/60000]
# loss: 0.874334  [19200/60000]
# loss: 0.754803  [25600/60000]
# loss: 0.758450  [32000/60000]
# loss: 0.840448  [38400/60000]
# loss: 0.806152  [44800/60000]
# loss: 0.830361  [51200/60000]
# loss: 0.790279  [57600/60000]
# Average Train loss: 0.786659
# Test Error:
#  Accuracy: 71.0%, Avg loss: 0.787270
#
# Epoch 12
# ------------------------------
# loss: 0.792355  [    0/60000]
# loss: 0.875316  [ 6400/60000]
# loss: 0.629408  [12800/60000]
# loss: 0.845040  [19200/60000]
# loss: 0.729484  [25600/60000]
# loss: 0.727121  [32000/60000]
# loss: 0.811044  [38400/60000]
# loss: 0.784910  [44800/60000]
# loss: 0.803684  [51200/60000]
# loss: 0.765560  [57600/60000]
# Average Train loss: 0.757312
# Test Error:
#  Accuracy: 72.0%, Avg loss: 0.761109
#
# Epoch 13
# ------------------------------
# loss: 0.754805  [    0/60000]
# loss: 0.844647  [ 6400/60000]
# loss: 0.597237  [12800/60000]
# loss: 0.821054  [19200/60000]
# loss: 0.708404  [25600/60000]
# loss: 0.702087  [32000/60000]
# loss: 0.784898  [38400/60000]
# loss: 0.766939  [44800/60000]
# loss: 0.781450  [51200/60000]
# loss: 0.744212  [57600/60000]
# Average Train loss: 0.732551
# Test Error:
#  Accuracy: 73.0%, Avg loss: 0.738631
#
# Epoch 14
# ------------------------------
# loss: 0.722242  [    0/60000]
# loss: 0.817048  [ 6400/60000]
# loss: 0.569950  [12800/60000]
# loss: 0.800894  [19200/60000]
# loss: 0.690411  [25600/60000]
# loss: 0.681594  [32000/60000]
# loss: 0.761251  [38400/60000]
# loss: 0.751182  [44800/60000]
# loss: 0.762318  [51200/60000]
# loss: 0.725315  [57600/60000]
# Average Train loss: 0.711009
# Test Error:
#  Accuracy: 74.1%, Avg loss: 0.718818
#
# Epoch 15
# ------------------------------
# loss: 0.693647  [    0/60000]
# loss: 0.791964  [ 6400/60000]
# loss: 0.546451  [12800/60000]
# loss: 0.783421  [19200/60000]
# loss: 0.674884  [25600/60000]
# loss: 0.664446  [32000/60000]
# loss: 0.739596  [38400/60000]
# loss: 0.737056  [44800/60000]
# loss: 0.745730  [51200/60000]
# loss: 0.708369  [57600/60000]
# Average Train loss: 0.691842
# Test Error:
#  Accuracy: 75.0%, Avg loss: 0.701055
#
# Epoch 16
# ------------------------------
# loss: 0.668298  [    0/60000]
# loss: 0.768978  [ 6400/60000]
# loss: 0.526004  [12800/60000]
# loss: 0.768026  [19200/60000]
# loss: 0.661351  [25600/60000]
# loss: 0.649874  [32000/60000]
# loss: 0.719585  [38400/60000]
# loss: 0.724267  [44800/60000]
# loss: 0.731258  [51200/60000]
# loss: 0.692874  [57600/60000]
# Average Train loss: 0.674535
# Test Error:
#  Accuracy: 75.9%, Avg loss: 0.684951
#
# Epoch 17
# ------------------------------
# loss: 0.645684  [    0/60000]
# loss: 0.747922  [ 6400/60000]
# loss: 0.508109  [12800/60000]
# loss: 0.754122  [19200/60000]
# loss: 0.649341  [25600/60000]
# loss: 0.637418  [32000/60000]
# loss: 0.701122  [38400/60000]
# loss: 0.712669  [44800/60000]
# loss: 0.718589  [51200/60000]
# loss: 0.678686  [57600/60000]
# Average Train loss: 0.658765
# Test Error:
#  Accuracy: 76.5%, Avg loss: 0.670273
#
# Epoch 18
# ------------------------------
# loss: 0.625491  [    0/60000]
# loss: 0.728649  [ 6400/60000]
# loss: 0.492396  [12800/60000]
# loss: 0.741360  [19200/60000]
# loss: 0.638795  [25600/60000]
# loss: 0.626675  [32000/60000]
# loss: 0.684061  [38400/60000]
# loss: 0.702138  [44800/60000]
# loss: 0.707627  [51200/60000]
# loss: 0.665579  [57600/60000]
# Average Train loss: 0.644301
# Test Error:
#  Accuracy: 77.0%, Avg loss: 0.656820
#
# Epoch 19
# ------------------------------
# loss: 0.607421  [    0/60000]
# loss: 0.710867  [ 6400/60000]
# loss: 0.478384  [12800/60000]
# loss: 0.729612  [19200/60000]
# loss: 0.629321  [25600/60000]
# loss: 0.617392  [32000/60000]
# loss: 0.668181  [38400/60000]
# loss: 0.692825  [44800/60000]
# loss: 0.698154  [51200/60000]
# loss: 0.653363  [57600/60000]
# Average Train loss: 0.630990
# Test Error:
#  Accuracy: 77.5%, Avg loss: 0.644490
#
# Epoch 20
# ------------------------------
# loss: 0.591091  [    0/60000]
# loss: 0.694532  [ 6400/60000]
# loss: 0.465774  [12800/60000]
# loss: 0.718828  [19200/60000]
# loss: 0.620723  [25600/60000]
# loss: 0.609002  [32000/60000]
# loss: 0.653482  [38400/60000]
# loss: 0.684817  [44800/60000]
# loss: 0.689917  [51200/60000]
# loss: 0.641841  [57600/60000]
# Average Train loss: 0.618742
# Test Error:
#  Accuracy: 77.9%, Avg loss: 0.633175
#
# Epoch 21
# ------------------------------
# loss: 0.576304  [    0/60000]
# loss: 0.679611  [ 6400/60000]
# loss: 0.454326  [12800/60000]
# loss: 0.708775  [19200/60000]
# loss: 0.612803  [25600/60000]
# loss: 0.601494  [32000/60000]
# loss: 0.639883  [38400/60000]
# loss: 0.677907  [44800/60000]
# loss: 0.682830  [51200/60000]
# loss: 0.630987  [57600/60000]
# Average Train loss: 0.607437
# Test Error:
#  Accuracy: 78.2%, Avg loss: 0.622758
#
# Epoch 22
# ------------------------------
# loss: 0.562768  [    0/60000]
# loss: 0.665911  [ 6400/60000]
# loss: 0.443858  [12800/60000]
# loss: 0.699286  [19200/60000]
# loss: 0.605428  [25600/60000]
# loss: 0.594658  [32000/60000]
# loss: 0.627336  [38400/60000]
# loss: 0.672033  [44800/60000]
# loss: 0.676687  [51200/60000]
# loss: 0.620640  [57600/60000]
# Average Train loss: 0.596972
# Test Error:
#  Accuracy: 78.6%, Avg loss: 0.613142
#
# Epoch 23
# ------------------------------
# loss: 0.550320  [    0/60000]
# loss: 0.653286  [ 6400/60000]
# loss: 0.434280  [12800/60000]
# loss: 0.690277  [19200/60000]
# loss: 0.598469  [25600/60000]
# loss: 0.588336  [32000/60000]
# loss: 0.615774  [38400/60000]
# loss: 0.667150  [44800/60000]
# loss: 0.671311  [51200/60000]
# loss: 0.610794  [57600/60000]
# Average Train loss: 0.587262
# Test Error:
#  Accuracy: 79.0%, Avg loss: 0.604251
#
# Epoch 24
# ------------------------------
# loss: 0.538791  [    0/60000]
# loss: 0.641654  [ 6400/60000]
# loss: 0.425441  [12800/60000]
# loss: 0.681676  [19200/60000]
# loss: 0.591825  [25600/60000]
# loss: 0.582394  [32000/60000]
# loss: 0.605085  [38400/60000]
# loss: 0.663167  [44800/60000]
# loss: 0.666586  [51200/60000]
# loss: 0.601326  [57600/60000]
# Average Train loss: 0.578235
# Test Error:
#  Accuracy: 79.4%, Avg loss: 0.596002
#
# Epoch 25
# ------------------------------
# loss: 0.528049  [    0/60000]
# loss: 0.630961  [ 6400/60000]
# loss: 0.417229  [12800/60000]
# loss: 0.673449  [19200/60000]
# loss: 0.585416  [25600/60000]
# loss: 0.576724  [32000/60000]
# loss: 0.595121  [38400/60000]
# loss: 0.659985  [44800/60000]
# loss: 0.662458  [51200/60000]
# loss: 0.592120  [57600/60000]
# Average Train loss: 0.569820
# Test Error:
#  Accuracy: 79.6%, Avg loss: 0.588337
#
# Epoch 26
# ------------------------------
# loss: 0.517943  [    0/60000]
# loss: 0.621100  [ 6400/60000]
# loss: 0.409562  [12800/60000]
# loss: 0.665532  [19200/60000]
# loss: 0.579124  [25600/60000]
# loss: 0.571237  [32000/60000]
# loss: 0.585915  [38400/60000]
# loss: 0.657595  [44800/60000]
# loss: 0.658851  [51200/60000]
# loss: 0.583191  [57600/60000]
# Average Train loss: 0.561965
# Test Error:
#  Accuracy: 79.7%, Avg loss: 0.581198
#
# Epoch 27
# ------------------------------
# loss: 0.508407  [    0/60000]
# loss: 0.611987  [ 6400/60000]
# loss: 0.402377  [12800/60000]
# loss: 0.657940  [19200/60000]
# loss: 0.572965  [25600/60000]
# loss: 0.565967  [32000/60000]
# loss: 0.577457  [38400/60000]
# loss: 0.655815  [44800/60000]
# loss: 0.655832  [51200/60000]
# loss: 0.574554  [57600/60000]
# Average Train loss: 0.554626
# Test Error:
#  Accuracy: 80.0%, Avg loss: 0.574541
#
# Epoch 28
# ------------------------------
# loss: 0.499354  [    0/60000]
# loss: 0.603550  [ 6400/60000]
# loss: 0.395679  [12800/60000]
# loss: 0.650657  [19200/60000]
# loss: 0.566814  [25600/60000]
# loss: 0.560858  [32000/60000]
# loss: 0.569635  [38400/60000]
# loss: 0.654591  [44800/60000]
# loss: 0.653173  [51200/60000]
# loss: 0.566155  [57600/60000]
# Average Train loss: 0.547754
# Test Error:
#  Accuracy: 80.2%, Avg loss: 0.568316
#
# Epoch 29
# ------------------------------
# loss: 0.490723  [    0/60000]
# loss: 0.595738  [ 6400/60000]
# loss: 0.389391  [12800/60000]
# loss: 0.643656  [19200/60000]
# loss: 0.560742  [25600/60000]
# loss: 0.555848  [32000/60000]
# loss: 0.562412  [38400/60000]
# loss: 0.653862  [44800/60000]
# loss: 0.650775  [51200/60000]
# loss: 0.557932  [57600/60000]
# Average Train loss: 0.541309
# Test Error:
#  Accuracy: 80.5%, Avg loss: 0.562483
#
# Epoch 30
# ------------------------------
# loss: 0.482504  [    0/60000]
# loss: 0.588433  [ 6400/60000]
# loss: 0.383506  [12800/60000]
# loss: 0.636888  [19200/60000]
# loss: 0.554716  [25600/60000]
# loss: 0.550907  [32000/60000]
# loss: 0.555707  [38400/60000]
# loss: 0.653500  [44800/60000]
# loss: 0.648580  [51200/60000]
# loss: 0.549931  [57600/60000]
# Average Train loss: 0.535259
# Test Error:
#  Accuracy: 80.7%, Avg loss: 0.557011
#
# Epoch 31
# ------------------------------
# loss: 0.474717  [    0/60000]
# loss: 0.581646  [ 6400/60000]
# loss: 0.377953  [12800/60000]
# loss: 0.630362  [19200/60000]
# loss: 0.548763  [25600/60000]
# loss: 0.546051  [32000/60000]
# loss: 0.549434  [38400/60000]
# loss: 0.653482  [44800/60000]
# loss: 0.646637  [51200/60000]
# loss: 0.542140  [57600/60000]
# Average Train loss: 0.529573
# Test Error:
#  Accuracy: 80.9%, Avg loss: 0.551870
#
# Epoch 32
# ------------------------------
# loss: 0.467298  [    0/60000]
# loss: 0.575298  [ 6400/60000]
# loss: 0.372706  [12800/60000]
# loss: 0.624096  [19200/60000]
# loss: 0.542928  [25600/60000]
# loss: 0.541244  [32000/60000]
# loss: 0.543619  [38400/60000]
# loss: 0.653749  [44800/60000]
# loss: 0.644843  [51200/60000]
# loss: 0.534524  [57600/60000]
# Average Train loss: 0.524221
# Test Error:
#  Accuracy: 81.0%, Avg loss: 0.547035
#
# Epoch 33
# ------------------------------
# loss: 0.460250  [    0/60000]
# loss: 0.569347  [ 6400/60000]
# loss: 0.367837  [12800/60000]
# loss: 0.618067  [19200/60000]
# loss: 0.537183  [25600/60000]
# loss: 0.536439  [32000/60000]
# loss: 0.538246  [38400/60000]
# loss: 0.654279  [44800/60000]
# loss: 0.643131  [51200/60000]
# loss: 0.527211  [57600/60000]
# Average Train loss: 0.519181
# Test Error:
#  Accuracy: 81.1%, Avg loss: 0.542484
#
# Epoch 34
# ------------------------------
# loss: 0.453507  [    0/60000]
# loss: 0.563770  [ 6400/60000]
# loss: 0.363264  [12800/60000]
# loss: 0.612288  [19200/60000]
# loss: 0.531428  [25600/60000]
# loss: 0.531639  [32000/60000]
# loss: 0.533189  [38400/60000]
# loss: 0.654911  [44800/60000]
# loss: 0.641474  [51200/60000]
# loss: 0.520205  [57600/60000]
# Average Train loss: 0.514430
# Test Error:
#  Accuracy: 81.2%, Avg loss: 0.538195
#
# Epoch 35
# ------------------------------
# loss: 0.447017  [    0/60000]
# loss: 0.558523  [ 6400/60000]
# loss: 0.358995  [12800/60000]
# loss: 0.606723  [19200/60000]
# loss: 0.525731  [25600/60000]
# loss: 0.527034  [32000/60000]
# loss: 0.528443  [38400/60000]
# loss: 0.655653  [44800/60000]
# loss: 0.639754  [51200/60000]
# loss: 0.513403  [57600/60000]
# Average Train loss: 0.509948
# Test Error:
#  Accuracy: 81.3%, Avg loss: 0.534153
#
# Epoch 36
# ------------------------------
# loss: 0.440776  [    0/60000]
# loss: 0.553599  [ 6400/60000]
# loss: 0.354976  [12800/60000]
# loss: 0.601363  [19200/60000]
# loss: 0.520064  [25600/60000]
# loss: 0.522510  [32000/60000]
# loss: 0.524063  [38400/60000]
# loss: 0.656325  [44800/60000]
# loss: 0.638088  [51200/60000]
# loss: 0.506849  [57600/60000]
# Average Train loss: 0.505716
# Test Error:
#  Accuracy: 81.4%, Avg loss: 0.530342
#
# Epoch 37
# ------------------------------
# loss: 0.434804  [    0/60000]
# loss: 0.548987  [ 6400/60000]
# loss: 0.351099  [12800/60000]
# loss: 0.596143  [19200/60000]
# loss: 0.514608  [25600/60000]
# loss: 0.518097  [32000/60000]
# loss: 0.519900  [38400/60000]
# loss: 0.657018  [44800/60000]
# loss: 0.636429  [51200/60000]
# loss: 0.500488  [57600/60000]
# Average Train loss: 0.501719
# Test Error:
#  Accuracy: 81.5%, Avg loss: 0.526745
#
# Epoch 38
# ------------------------------
# loss: 0.429095  [    0/60000]
# loss: 0.544711  [ 6400/60000]
# loss: 0.347301  [12800/60000]
# loss: 0.590994  [19200/60000]
# loss: 0.509251  [25600/60000]
# loss: 0.513897  [32000/60000]
# loss: 0.516029  [38400/60000]
# loss: 0.657689  [44800/60000]
# loss: 0.634819  [51200/60000]
# loss: 0.494327  [57600/60000]
# Average Train loss: 0.497939
# Test Error:
#  Accuracy: 81.7%, Avg loss: 0.523349
#
# Epoch 39
# ------------------------------
# loss: 0.423534  [    0/60000]
# loss: 0.540674  [ 6400/60000]
# loss: 0.343717  [12800/60000]
# loss: 0.586154  [19200/60000]
# loss: 0.504091  [25600/60000]
# loss: 0.509815  [32000/60000]
# loss: 0.512348  [38400/60000]
# loss: 0.658379  [44800/60000]
# loss: 0.633279  [51200/60000]
# loss: 0.488396  [57600/60000]
# Average Train loss: 0.494367
# Test Error:
#  Accuracy: 81.8%, Avg loss: 0.520140
#
# Epoch 40
# ------------------------------
# loss: 0.418170  [    0/60000]
# loss: 0.536912  [ 6400/60000]
# loss: 0.340342  [12800/60000]
# loss: 0.581502  [19200/60000]
# loss: 0.499100  [25600/60000]
# loss: 0.505826  [32000/60000]
# loss: 0.508860  [38400/60000]
# loss: 0.658954  [44800/60000]
# loss: 0.631747  [51200/60000]
# loss: 0.482735  [57600/60000]
# Average Train loss: 0.490982
# Test Error:
#  Accuracy: 81.8%, Avg loss: 0.517100
#
# Epoch 41
# ------------------------------
# loss: 0.413000  [    0/60000]
# loss: 0.533363  [ 6400/60000]
# loss: 0.337120  [12800/60000]
# loss: 0.577044  [19200/60000]
# loss: 0.494318  [25600/60000]
# loss: 0.501951  [32000/60000]
# loss: 0.505549  [38400/60000]
# loss: 0.659414  [44800/60000]
# loss: 0.630131  [51200/60000]
# loss: 0.477362  [57600/60000]
# Average Train loss: 0.487766
# Test Error:
#  Accuracy: 81.8%, Avg loss: 0.514216
#
# Epoch 42
# ------------------------------
# loss: 0.408012  [    0/60000]
# loss: 0.530016  [ 6400/60000]
# loss: 0.334081  [12800/60000]
# loss: 0.572785  [19200/60000]
# loss: 0.489690  [25600/60000]
# loss: 0.498273  [32000/60000]
# loss: 0.502427  [38400/60000]
# loss: 0.659658  [44800/60000]
# loss: 0.628559  [51200/60000]
# loss: 0.472291  [57600/60000]
# Average Train loss: 0.484710
# Test Error:
#  Accuracy: 81.9%, Avg loss: 0.511478
#
# Epoch 43
# ------------------------------
# loss: 0.403124  [    0/60000]
# loss: 0.526807  [ 6400/60000]
# loss: 0.331247  [12800/60000]
# loss: 0.568691  [19200/60000]
# loss: 0.485200  [25600/60000]
# loss: 0.494770  [32000/60000]
# loss: 0.499510  [38400/60000]
# loss: 0.659702  [44800/60000]
# loss: 0.626956  [51200/60000]
# loss: 0.467503  [57600/60000]
# Average Train loss: 0.481801
# Test Error:
#  Accuracy: 81.9%, Avg loss: 0.508869
#
# Epoch 44
# ------------------------------
# loss: 0.398386  [    0/60000]
# loss: 0.523760  [ 6400/60000]
# loss: 0.328605  [12800/60000]
# loss: 0.564783  [19200/60000]
# loss: 0.480865  [25600/60000]
# loss: 0.491317  [32000/60000]
# loss: 0.496812  [38400/60000]
# loss: 0.659641  [44800/60000]
# loss: 0.625333  [51200/60000]
# loss: 0.462959  [57600/60000]
# Average Train loss: 0.479021
# Test Error:
#  Accuracy: 82.1%, Avg loss: 0.506381
#
# Epoch 45
# ------------------------------
# loss: 0.393783  [    0/60000]
# loss: 0.520848  [ 6400/60000]
# loss: 0.326115  [12800/60000]
# loss: 0.561041  [19200/60000]
# loss: 0.476675  [25600/60000]
# loss: 0.488098  [32000/60000]
# loss: 0.494182  [38400/60000]
# loss: 0.659434  [44800/60000]
# loss: 0.623647  [51200/60000]
# loss: 0.458688  [57600/60000]
# Average Train loss: 0.476362
# Test Error:
#  Accuracy: 82.1%, Avg loss: 0.504007
#
# Epoch 46
# ------------------------------
# loss: 0.389287  [    0/60000]
# loss: 0.518103  [ 6400/60000]
# loss: 0.323792  [12800/60000]
# loss: 0.557440  [19200/60000]
# loss: 0.472606  [25600/60000]
# loss: 0.485011  [32000/60000]
# loss: 0.491543  [38400/60000]
# loss: 0.659053  [44800/60000]
# loss: 0.621952  [51200/60000]
# loss: 0.454628  [57600/60000]
# Average Train loss: 0.473813
# Test Error:
#  Accuracy: 82.3%, Avg loss: 0.501734
#
# Epoch 47
# ------------------------------
# loss: 0.384952  [    0/60000]
# loss: 0.515414  [ 6400/60000]
# loss: 0.321599  [12800/60000]
# loss: 0.553972  [19200/60000]
# loss: 0.468653  [25600/60000]
# loss: 0.482066  [32000/60000]
# loss: 0.489023  [38400/60000]
# loss: 0.658482  [44800/60000]
# loss: 0.620301  [51200/60000]
# loss: 0.450843  [57600/60000]
# Average Train loss: 0.471366
# Test Error:
#  Accuracy: 82.3%, Avg loss: 0.499556
#
# Epoch 48
# ------------------------------
# loss: 0.380776  [    0/60000]
# loss: 0.512855  [ 6400/60000]
# loss: 0.319501  [12800/60000]
# loss: 0.550529  [19200/60000]
# loss: 0.464875  [25600/60000]
# loss: 0.479173  [32000/60000]
# loss: 0.486616  [38400/60000]
# loss: 0.657829  [44800/60000]
# loss: 0.618612  [51200/60000]
# loss: 0.447238  [57600/60000]
# Average Train loss: 0.469015
# Test Error:
#  Accuracy: 82.4%, Avg loss: 0.497459
#
# Epoch 49
# ------------------------------
# loss: 0.376731  [    0/60000]
# loss: 0.510402  [ 6400/60000]
# loss: 0.317418  [12800/60000]
# loss: 0.547351  [19200/60000]
# loss: 0.461179  [25600/60000]
# loss: 0.476361  [32000/60000]
# loss: 0.484348  [38400/60000]
# loss: 0.657061  [44800/60000]
# loss: 0.616934  [51200/60000]
# loss: 0.443787  [57600/60000]
# Average Train loss: 0.466756
# Test Error:
#  Accuracy: 82.4%, Avg loss: 0.495458
#
# Epoch 50
# ------------------------------
# loss: 0.372772  [    0/60000]
# loss: 0.508095  [ 6400/60000]
# loss: 0.315405  [12800/60000]
# loss: 0.544265  [19200/60000]
# loss: 0.457611  [25600/60000]
# loss: 0.473633  [32000/60000]
# loss: 0.482196  [38400/60000]
# loss: 0.656187  [44800/60000]
# loss: 0.615223  [51200/60000]
# loss: 0.440569  [57600/60000]
# Average Train loss: 0.464582
# Test Error:
#  Accuracy: 82.4%, Avg loss: 0.493535
#
# Epoch 51
# ------------------------------
# loss: 0.368987  [    0/60000]
# loss: 0.505876  [ 6400/60000]
# loss: 0.313493  [12800/60000]
# loss: 0.541271  [19200/60000]
# loss: 0.454120  [25600/60000]
# loss: 0.471003  [32000/60000]
# loss: 0.480055  [38400/60000]
# loss: 0.655209  [44800/60000]
# loss: 0.613579  [51200/60000]
# loss: 0.437480  [57600/60000]
# Average Train loss: 0.462487
# Test Error:
#  Accuracy: 82.5%, Avg loss: 0.491678
#
# Epoch 52
# ------------------------------
# loss: 0.365342  [    0/60000]
# loss: 0.503786  [ 6400/60000]
# loss: 0.311629  [12800/60000]
# loss: 0.538444  [19200/60000]
# loss: 0.450708  [25600/60000]
# loss: 0.468392  [32000/60000]
# loss: 0.477922  [38400/60000]
# loss: 0.654196  [44800/60000]
# loss: 0.611913  [51200/60000]
# loss: 0.434561  [57600/60000]
# Average Train loss: 0.460462
# Test Error:
#  Accuracy: 82.5%, Avg loss: 0.489887
#
# Epoch 53
# ------------------------------
# loss: 0.361810  [    0/60000]
# loss: 0.501697  [ 6400/60000]
# loss: 0.309874  [12800/60000]
# loss: 0.535688  [19200/60000]
# loss: 0.447456  [25600/60000]
# loss: 0.465855  [32000/60000]
# loss: 0.475846  [38400/60000]
# loss: 0.653162  [44800/60000]
# loss: 0.610313  [51200/60000]
# loss: 0.431795  [57600/60000]
# Average Train loss: 0.458504
# Test Error:
#  Accuracy: 82.7%, Avg loss: 0.488155
#
# Epoch 54
# ------------------------------
# loss: 0.358366  [    0/60000]
# loss: 0.499640  [ 6400/60000]
# loss: 0.308171  [12800/60000]
# loss: 0.533013  [19200/60000]
# loss: 0.444242  [25600/60000]
# loss: 0.463393  [32000/60000]
# loss: 0.473820  [38400/60000]
# loss: 0.652050  [44800/60000]
# loss: 0.608723  [51200/60000]
# loss: 0.429130  [57600/60000]
# Average Train loss: 0.456609
# Test Error:
#  Accuracy: 82.7%, Avg loss: 0.486478
#
# Epoch 55
# ------------------------------
# loss: 0.354989  [    0/60000]
# loss: 0.497645  [ 6400/60000]
# loss: 0.306506  [12800/60000]
# loss: 0.530462  [19200/60000]
# loss: 0.441112  [25600/60000]
# loss: 0.461012  [32000/60000]
# loss: 0.471908  [38400/60000]
# loss: 0.650838  [44800/60000]
# loss: 0.607074  [51200/60000]
# loss: 0.426598  [57600/60000]
# Average Train loss: 0.454770
# Test Error:
#  Accuracy: 82.8%, Avg loss: 0.484854
#
# Epoch 56
# ------------------------------
# loss: 0.351752  [    0/60000]
# loss: 0.495665  [ 6400/60000]
# loss: 0.304872  [12800/60000]
# loss: 0.528029  [19200/60000]
# loss: 0.438031  [25600/60000]
# loss: 0.458736  [32000/60000]
# loss: 0.470031  [38400/60000]
# loss: 0.649609  [44800/60000]
# loss: 0.605499  [51200/60000]
# loss: 0.424193  [57600/60000]
# Average Train loss: 0.452986
# Test Error:
#  Accuracy: 82.8%, Avg loss: 0.483279
#
# Epoch 57
# ------------------------------
# loss: 0.348528  [    0/60000]
# loss: 0.493765  [ 6400/60000]
# loss: 0.303263  [12800/60000]
# loss: 0.525649  [19200/60000]
# loss: 0.435022  [25600/60000]
# loss: 0.456586  [32000/60000]
# loss: 0.468186  [38400/60000]
# loss: 0.648303  [44800/60000]
# loss: 0.603924  [51200/60000]
# loss: 0.421932  [57600/60000]
# Average Train loss: 0.451251
# Test Error:
#  Accuracy: 82.9%, Avg loss: 0.481757
#
# Epoch 58
# ------------------------------
# loss: 0.345366  [    0/60000]
# loss: 0.491849  [ 6400/60000]
# loss: 0.301692  [12800/60000]
# loss: 0.523319  [19200/60000]
# loss: 0.432162  [25600/60000]
# loss: 0.454506  [32000/60000]
# loss: 0.466400  [38400/60000]
# loss: 0.646925  [44800/60000]
# loss: 0.602405  [51200/60000]
# loss: 0.419837  [57600/60000]
# Average Train loss: 0.449565
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.480281
#
# Epoch 59
# ------------------------------
# loss: 0.342253  [    0/60000]
# loss: 0.489932  [ 6400/60000]
# loss: 0.300171  [12800/60000]
# loss: 0.521051  [19200/60000]
# loss: 0.429385  [25600/60000]
# loss: 0.452524  [32000/60000]
# loss: 0.464669  [38400/60000]
# loss: 0.645509  [44800/60000]
# loss: 0.600967  [51200/60000]
# loss: 0.417821  [57600/60000]
# Average Train loss: 0.447923
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.478840
#
# Epoch 60
# ------------------------------
# loss: 0.339239  [    0/60000]
# loss: 0.488059  [ 6400/60000]
# loss: 0.298721  [12800/60000]
# loss: 0.518879  [19200/60000]
# loss: 0.426650  [25600/60000]
# loss: 0.450675  [32000/60000]
# loss: 0.462997  [38400/60000]
# loss: 0.643995  [44800/60000]
# loss: 0.599500  [51200/60000]
# loss: 0.415905  [57600/60000]
# Average Train loss: 0.446320
# Test Error:
#  Accuracy: 83.1%, Avg loss: 0.477444
#
# Epoch 61
# ------------------------------
# loss: 0.336299  [    0/60000]
# loss: 0.486167  [ 6400/60000]
# loss: 0.297302  [12800/60000]
# loss: 0.516761  [19200/60000]
# loss: 0.423984  [25600/60000]
# loss: 0.448748  [32000/60000]
# loss: 0.461347  [38400/60000]
# loss: 0.642351  [44800/60000]
# loss: 0.598069  [51200/60000]
# loss: 0.414038  [57600/60000]
# Average Train loss: 0.444755
# Test Error:
#  Accuracy: 83.1%, Avg loss: 0.476077
#
# Stopped after 60 epochs without reaching 85% accuracy. Best accuracy: 0.830900
# Done!

# %%
# Print the best accuracy and the best epoch
for lr in learning_rates:

    best_accuracy = result_to_85[lr]['best_accuracy']
    best_epoch = result_to_85[lr]['best_epoch']
    
    print(f"Learning rate {lr} - Best Accuracy: {round(best_accuracy *100, 4)}% achieved in epoch {best_epoch}")
# Out:
# Learning rate 1 - Best Accuracy: 300% achieved in epoch 0.3008
# Learning rate 0.1 - Best Accuracy: 500% achieved in epoch 0.8571
# Learning rate 0.01 - Best Accuracy: 1700% achieved in epoch 0.8519
# Learning rate 0.001 - Best Accuracy: 6000% achieved in epoch 0.8309

# %%
# Plot training loss for different learning rates
plt.figure(figsize=(20, 14))
for lr in learning_rates:
    train_losses = result_to_85[lr]['train_losses']
    plt.plot(range(1, len(train_losses) + 1), train_losses, label=f'Training Loss (lr={lr})')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training Loss for model using Different Learning Rates')
plt.legend()
plt.show()

# Plot test loss for different learning rates
plt.figure(figsize=(20, 14))
for lr in learning_rates:
    test_losses = result_to_85[lr]['test_losses']
    plt.plot(range(1, len(test_losses) + 1), test_losses, label=f'Test Loss (lr={lr})')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Test Loss for model using Different Learning Rates')
plt.legend()
plt.show()

# Plot accuracy for different learning rates
plt.figure(figsize=(20, 14))
for lr in learning_rates:
    accuracies = result_to_85[lr]['accuracy_list']
    plt.plot(range(1, len(accuracies) + 1), accuracies, label=f'Accuracy (lr={lr})')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Accuracy for model using Different Learning Rates')
plt.legend()
plt.show()

# %% [markdown]
# Report the number of epochs when the accuracy reaches 85%. The table below shows the results:
# |Lr|Accuracy|Epoch|
# |---|---|---|
# |1   |      |     |
# |0.1|          |    |
# |0.01|         |    |
# |0.001  |        |     |

# %% [markdown]
# **Q1.4 (2 points)**
#
# Compare the results in table 1 and table 2, what is your observation and your understanding of learning rate?

# %% [markdown]
# **Q1.5 (5 points)**
#
# Build a wider network by modifying the code that constructs the network so that the hidden layer(s) contain more perceptrons, and record the accuracy along with the number of trainable parameters in your model.  Now modify the oroginal network to be deeper instead of wider (i.e. by adding more hidden layers). Record your accuracy and network size findings. Plot the loss curve for each experiment. Write down your conclusions about changing the network structure?
#
# |Structures|Accuracy|Parameters|
# |---|---|---|
# |Base   |      ||
# |Deeper|          ||
# |Wider|         ||

# %%
# Wider model
class WiderNeuralNetwork(nn.Module):
    def __init__(self):
        super(WiderNeuralNetwork, self).__init__()
        self.flatten = nn.Flatten()
        self.linear_relu_stack = nn.Sequential(
            nn.Linear(28*28, 1024),
            nn.ReLU(),
            nn.Linear(1024, 1024),
            nn.ReLU(),
            nn.Linear(1024, 10)
        )

    def forward(self, x):
        x = self.flatten(x)
        logits = self.linear_relu_stack(x)
        return logits

# %%
# Deeper model
class DeeperNeuralNetwork(nn.Module):
    def __init__(self):
        super(DeeperNeuralNetwork, self).__init__()
        self.flatten = nn.Flatten()
        self.linear_relu_stack = nn.Sequential(
            nn.Linear(28*28, 512),
            nn.ReLU(),
            nn.Linear(512, 512),
            nn.ReLU(),
            nn.Linear(512, 512),
            nn.ReLU(),
            nn.Linear(512, 10)
        )

    def forward(self, x):
        x = self.flatten(x)
        logits = self.linear_relu_stack(x)
        return logits

# %%
# Count the number of tainable parameters
def number_of_trainable_params(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %%
def train_and_evaluate_structures(model, epochs=10):
    test_losses = []
    accuracy_list = []
    train_losses = []
    
        
    optimizer = torch.optim.SGD(model.parameters(), lr=0.1)

    parammeters = number_of_trainable_params(model)

    for t in range(epochs):
        print(f"Epoch {t+1}\n{'-' * 30}")

        train_loss = train(train_dataloader, model, loss_fn, optimizer)
        test_loss, correct = test(test_dataloader, model, loss_fn)

        train_losses.append(train_loss)
        test_losses.append(test_loss)
        accuracy_list.append(correct)

    print(f"Accuracy after {epochs} epochs: {correct:>6f}")

    return train_losses, test_losses, accuracy_list, parammeters

# %%
# List of models to try
model_variants = [
    "Base Model",
    "Wider Model",
    "Deeper Model"
]

results_summary = {}

# Training loop for different models
for variant in model_variants:
    print(f"\nTraining with model variant: {variant}")
    set_seed(42)
    
    if variant == "Wider Model":
        current_model = WiderNeuralNetwork().to(device)
    elif variant == "Deeper Model":
        current_model = DeeperNeuralNetwork().to(device)
    else:
        current_model = NeuralNetwork().to(device)
    
    train_losses, test_losses, accuracy_list, params_count = train_and_evaluate_structures(current_model, epochs=15)
    
    results_summary[variant] = {
        'train_losses': train_losses,
        'test_losses': test_losses,
        'accuracy_list': accuracy_list,
        'params_count': params_count
    }

# Display the results
for variant in model_variants:
    final_accuracy = results_summary[variant]['accuracy_list'][-1]
    total_params = results_summary[variant]['params_count']
    
    print(f"\nModel Variant: {variant}")
    print(f"Number of trainable parameters: {total_params}")
    print(f"Final Accuracy after 15 epochs: {final_accuracy * 100:.2f}%")
# Out:
# Training with model variant: Base Model
# Epoch 1
# ------------------------------
# loss: 2.298730  [    0/60000]
# loss: 0.908623  [ 6400/60000]
# loss: 0.580196  [12800/60000]
# loss: 0.720629  [19200/60000]
# loss: 0.614350  [25600/60000]
# loss: 0.500302  [32000/60000]
# loss: 0.540581  [38400/60000]
# loss: 0.599433  [44800/60000]
# loss: 0.616562  [51200/60000]
# loss: 0.458594  [57600/60000]
# Average Train loss: 0.654657
# Test Error:
#  Accuracy: 78.1%, Avg loss: 0.571193
#
# Epoch 2
# ------------------------------
# loss: 0.465054  [    0/60000]
# loss: 0.442642  [ 6400/60000]
# loss: 0.377082  [12800/60000]
# loss: 0.440151  [19200/60000]
# loss: 0.403445  [25600/60000]
# loss: 0.436655  [32000/60000]
# loss: 0.406358  [38400/60000]
# loss: 0.507337  [44800/60000]
# loss: 0.526519  [51200/60000]
# loss: 0.432994  [57600/60000]
# Average Train loss: 0.424438
# Test Error:
#  Accuracy: 81.3%, Avg loss: 0.488511
#
# Epoch 3
# ------------------------------
# loss: 0.358920  [    0/60000]
# loss: 0.366159  [ 6400/60000]
# loss: 0.310650  [12800/60000]
# loss: 0.365913  [19200/60000]
# loss: 0.336239  [25600/60000]
# loss: 0.408728  [32000/60000]
# loss: 0.349020  [38400/60000]
# loss: 0.467654  [44800/60000]
# loss: 0.465646  [51200/60000]
# loss: 0.415533  [57600/60000]
# Average Train loss: 0.375505
# Test Error:
#  Accuracy: 83.2%, Avg loss: 0.446801
#
# Epoch 4
# ------------------------------
# loss: 0.290721  [    0/60000]
# loss: 0.334928  [ 6400/60000]
# loss: 0.265934  [12800/60000]
# loss: 0.319810  [19200/60000]
# loss: 0.319318  [25600/60000]
# loss: 0.390072  [32000/60000]
# loss: 0.320641  [38400/60000]
# loss: 0.418341  [44800/60000]
# loss: 0.431594  [51200/60000]
# loss: 0.401941  [57600/60000]
# Average Train loss: 0.344942
# Test Error:
#  Accuracy: 84.4%, Avg loss: 0.415021
#
# Epoch 5
# ------------------------------
# loss: 0.251623  [    0/60000]
# loss: 0.310359  [ 6400/60000]
# loss: 0.229984  [12800/60000]
# loss: 0.302930  [19200/60000]
# loss: 0.300974  [25600/60000]
# loss: 0.375038  [32000/60000]
# loss: 0.295272  [38400/60000]
# loss: 0.381145  [44800/60000]
# loss: 0.404316  [51200/60000]
# loss: 0.380406  [57600/60000]
# Average Train loss: 0.322477
# Test Error:
#  Accuracy: 85.7%, Avg loss: 0.389594
#
# Epoch 6
# ------------------------------
# loss: 0.223772  [    0/60000]
# loss: 0.287521  [ 6400/60000]
# loss: 0.215778  [12800/60000]
# loss: 0.271372  [19200/60000]
# loss: 0.289058  [25600/60000]
# loss: 0.365862  [32000/60000]
# loss: 0.280939  [38400/60000]
# loss: 0.363203  [44800/60000]
# loss: 0.384423  [51200/60000]
# loss: 0.368786  [57600/60000]
# Average Train loss: 0.304477
# Test Error:
#  Accuracy: 86.0%, Avg loss: 0.371941
#
# Epoch 7
# ------------------------------
# loss: 0.213792  [    0/60000]
# loss: 0.273293  [ 6400/60000]
# loss: 0.195239  [12800/60000]
# loss: 0.252823  [19200/60000]
# loss: 0.280653  [25600/60000]
# loss: 0.348211  [32000/60000]
# loss: 0.256258  [38400/60000]
# loss: 0.328084  [44800/60000]
# loss: 0.371048  [51200/60000]
# loss: 0.348812  [57600/60000]
# Average Train loss: 0.289304
# Test Error:
#  Accuracy: 86.6%, Avg loss: 0.362419
#
# Epoch 8
# ------------------------------
# loss: 0.203672  [    0/60000]
# loss: 0.258862  [ 6400/60000]
# loss: 0.187886  [12800/60000]
# loss: 0.241832  [19200/60000]
# loss: 0.277331  [25600/60000]
# loss: 0.337186  [32000/60000]
# loss: 0.243633  [38400/60000]
# loss: 0.309428  [44800/60000]
# loss: 0.347340  [51200/60000]
# loss: 0.343401  [57600/60000]
# Average Train loss: 0.275754
# Test Error:
#  Accuracy: 87.1%, Avg loss: 0.355105
#
# Epoch 9
# ------------------------------
# loss: 0.190051  [    0/60000]
# loss: 0.250311  [ 6400/60000]
# loss: 0.179111  [12800/60000]
# loss: 0.227047  [19200/60000]
# loss: 0.265265  [25600/60000]
# loss: 0.324286  [32000/60000]
# loss: 0.235161  [38400/60000]
# loss: 0.303972  [44800/60000]
# loss: 0.339473  [51200/60000]
# loss: 0.336972  [57600/60000]
# Average Train loss: 0.263608
# Test Error:
#  Accuracy: 87.3%, Avg loss: 0.350590
#
# Epoch 10
# ------------------------------
# loss: 0.182916  [    0/60000]
# loss: 0.235876  [ 6400/60000]
# loss: 0.168496  [12800/60000]
# loss: 0.221832  [19200/60000]
# loss: 0.257252  [25600/60000]
# loss: 0.307938  [32000/60000]
# loss: 0.216700  [38400/60000]
# loss: 0.296519  [44800/60000]
# loss: 0.311959  [51200/60000]
# loss: 0.313996  [57600/60000]
# Average Train loss: 0.252720
# Test Error:
#  Accuracy: 87.8%, Avg loss: 0.341121
#
# Epoch 11
# ------------------------------
# loss: 0.170423  [    0/60000]
# loss: 0.223069  [ 6400/60000]
# loss: 0.163827  [12800/60000]
# loss: 0.205821  [19200/60000]
# loss: 0.244937  [25600/60000]
# loss: 0.293522  [32000/60000]
# loss: 0.205827  [38400/60000]
# loss: 0.270297  [44800/60000]
# loss: 0.293723  [51200/60000]
# loss: 0.304437  [57600/60000]
# Average Train loss: 0.242261
# Test Error:
#  Accuracy: 87.9%, Avg loss: 0.339731
#
# Epoch 12
# ------------------------------
# loss: 0.178047  [    0/60000]
# loss: 0.218225  [ 6400/60000]
# loss: 0.163225  [12800/60000]
# loss: 0.193094  [19200/60000]
# loss: 0.256125  [25600/60000]
# loss: 0.282314  [32000/60000]
# loss: 0.194421  [38400/60000]
# loss: 0.263575  [44800/60000]
# loss: 0.279800  [51200/60000]
# loss: 0.303665  [57600/60000]
# Average Train loss: 0.232800
# Test Error:
#  Accuracy: 87.8%, Avg loss: 0.342771
#
# Epoch 13
# ------------------------------
# loss: 0.181593  [    0/60000]
# loss: 0.201415  [ 6400/60000]
# loss: 0.157234  [12800/60000]
# loss: 0.187879  [19200/60000]
# loss: 0.243177  [25600/60000]
# loss: 0.268999  [32000/60000]
# loss: 0.189197  [38400/60000]
# loss: 0.258763  [44800/60000]
# loss: 0.264539  [51200/60000]
# loss: 0.276674  [57600/60000]
# Average Train loss: 0.223409
# Test Error:
#  Accuracy: 87.7%, Avg loss: 0.346049
#
# Epoch 14
# ------------------------------
# loss: 0.182112  [    0/60000]
# loss: 0.193605  [ 6400/60000]
# loss: 0.150290  [12800/60000]
# loss: 0.179166  [19200/60000]
# loss: 0.242892  [25600/60000]
# loss: 0.246919  [32000/60000]
# loss: 0.179747  [38400/60000]
# loss: 0.249119  [44800/60000]
# loss: 0.260210  [51200/60000]
# loss: 0.254636  [57600/60000]
# Average Train loss: 0.214480
# Test Error:
#  Accuracy: 87.9%, Avg loss: 0.340266
#
# Epoch 15
# ------------------------------
# loss: 0.165276  [    0/60000]
# loss: 0.185297  [ 6400/60000]
# loss: 0.141397  [12800/60000]
# loss: 0.176628  [19200/60000]
# loss: 0.237437  [25600/60000]
# loss: 0.229595  [32000/60000]
# loss: 0.170295  [38400/60000]
# loss: 0.253307  [44800/60000]
# loss: 0.253614  [51200/60000]
# loss: 0.235814  [57600/60000]
# Average Train loss: 0.206003
# Test Error:
#  Accuracy: 88.1%, Avg loss: 0.340398
#
# Accuracy after 15 epochs: 0.881200
#
# Training with model variant: Wider Model
# Epoch 1
# ------------------------------
# loss: 2.298975  [    0/60000]
# loss: 0.868392  [ 6400/60000]
# loss: 0.561384  [12800/60000]
# loss: 0.700233  [19200/60000]
# loss: 0.610332  [25600/60000]
# loss: 0.503610  [32000/60000]
# loss: 0.529134  [38400/60000]
# loss: 0.588539  [44800/60000]
# loss: 0.605628  [51200/60000]
# loss: 0.446218  [57600/60000]
# Average Train loss: 0.634748
# Test Error:
#  Accuracy: 79.2%, Avg loss: 0.545637
#
# Epoch 2
# ------------------------------
# loss: 0.430552  [    0/60000]
# loss: 0.418994  [ 6400/60000]
# loss: 0.358545  [12800/60000]
# loss: 0.425258  [19200/60000]
# loss: 0.426666  [25600/60000]
# loss: 0.438977  [32000/60000]
# loss: 0.410839  [38400/60000]
# loss: 0.502773  [44800/60000]
# loss: 0.502185  [51200/60000]
# loss: 0.411583  [57600/60000]
# Average Train loss: 0.415826
# Test Error:
#  Accuracy: 81.9%, Avg loss: 0.476579
#
# Epoch 3
# ------------------------------
# loss: 0.333930  [    0/60000]
# loss: 0.340728  [ 6400/60000]
# loss: 0.294959  [12800/60000]
# loss: 0.355394  [19200/60000]
# loss: 0.350015  [25600/60000]
# loss: 0.416359  [32000/60000]
# loss: 0.357637  [38400/60000]
# loss: 0.455803  [44800/60000]
# loss: 0.456056  [51200/60000]
# loss: 0.399174  [57600/60000]
# Average Train loss: 0.367423
# Test Error:
#  Accuracy: 83.7%, Avg loss: 0.429666
#
# Epoch 4
# ------------------------------
# loss: 0.271253  [    0/60000]
# loss: 0.306342  [ 6400/60000]
# loss: 0.253916  [12800/60000]
# loss: 0.323007  [19200/60000]
# loss: 0.312357  [25600/60000]
# loss: 0.399313  [32000/60000]
# loss: 0.327392  [38400/60000]
# loss: 0.413606  [44800/60000]
# loss: 0.417775  [51200/60000]
# loss: 0.393814  [57600/60000]
# Average Train loss: 0.337453
# Test Error:
#  Accuracy: 84.8%, Avg loss: 0.408474
#
# Epoch 5
# ------------------------------
# loss: 0.239363  [    0/60000]
# loss: 0.290051  [ 6400/60000]
# loss: 0.219738  [12800/60000]
# loss: 0.292583  [19200/60000]
# loss: 0.292112  [25600/60000]
# loss: 0.386363  [32000/60000]
# loss: 0.298294  [38400/60000]
# loss: 0.371906  [44800/60000]
# loss: 0.396925  [51200/60000]
# loss: 0.373068  [57600/60000]
# Average Train loss: 0.315126
# Test Error:
#  Accuracy: 85.5%, Avg loss: 0.388081
#
# Epoch 6
# ------------------------------
# loss: 0.214533  [    0/60000]
# loss: 0.277564  [ 6400/60000]
# loss: 0.200894  [12800/60000]
# loss: 0.274092  [19200/60000]
# loss: 0.279691  [25600/60000]
# loss: 0.370569  [32000/60000]
# loss: 0.270997  [38400/60000]
# loss: 0.343977  [44800/60000]
# loss: 0.369674  [51200/60000]
# loss: 0.372876  [57600/60000]
# Average Train loss: 0.297230
# Test Error:
#  Accuracy: 86.4%, Avg loss: 0.371105
#
# Epoch 7
# ------------------------------
# loss: 0.193859  [    0/60000]
# loss: 0.269289  [ 6400/60000]
# loss: 0.190154  [12800/60000]
# loss: 0.253046  [19200/60000]
# loss: 0.269923  [25600/60000]
# loss: 0.355048  [32000/60000]
# loss: 0.265148  [38400/60000]
# loss: 0.327844  [44800/60000]
# loss: 0.349900  [51200/60000]
# loss: 0.357472  [57600/60000]
# Average Train loss: 0.281653
# Test Error:
#  Accuracy: 87.0%, Avg loss: 0.356100
#
# Epoch 8
# ------------------------------
# loss: 0.182319  [    0/60000]
# loss: 0.256306  [ 6400/60000]
# loss: 0.177873  [12800/60000]
# loss: 0.231927  [19200/60000]
# loss: 0.262245  [25600/60000]
# loss: 0.346875  [32000/60000]
# loss: 0.244325  [38400/60000]
# loss: 0.303498  [44800/60000]
# loss: 0.335497  [51200/60000]
# loss: 0.348375  [57600/60000]
# Average Train loss: 0.267679
# Test Error:
#  Accuracy: 86.9%, Avg loss: 0.351530
#
# Epoch 9
# ------------------------------
# loss: 0.175662  [    0/60000]
# loss: 0.231295  [ 6400/60000]
# loss: 0.172710  [12800/60000]
# loss: 0.224848  [19200/60000]
# loss: 0.256215  [25600/60000]
# loss: 0.334292  [32000/60000]
# loss: 0.239505  [38400/60000]
# loss: 0.283297  [44800/60000]
# loss: 0.311879  [51200/60000]
# loss: 0.340904  [57600/60000]
# Average Train loss: 0.254980
# Test Error:
#  Accuracy: 87.5%, Avg loss: 0.340366
#
# Epoch 10
# ------------------------------
# loss: 0.164775  [    0/60000]
# loss: 0.232199  [ 6400/60000]
# loss: 0.166779  [12800/60000]
# loss: 0.207255  [19200/60000]
# loss: 0.258733  [25600/60000]
# loss: 0.312917  [32000/60000]
# loss: 0.222848  [38400/60000]
# loss: 0.271584  [44800/60000]
# loss: 0.302469  [51200/60000]
# loss: 0.314258  [57600/60000]
# Average Train loss: 0.243120
# Test Error:
#  Accuracy: 87.5%, Avg loss: 0.340691
#
# Epoch 11
# ------------------------------
# loss: 0.163723  [    0/60000]
# loss: 0.219359  [ 6400/60000]
# loss: 0.158734  [12800/60000]
# loss: 0.200913  [19200/60000]
# loss: 0.247536  [25600/60000]
# loss: 0.305387  [32000/60000]
# loss: 0.205692  [38400/60000]
# loss: 0.257701  [44800/60000]
# loss: 0.291677  [51200/60000]
# loss: 0.316878  [57600/60000]
# Average Train loss: 0.232520
# Test Error:
#  Accuracy: 88.0%, Avg loss: 0.332212
#
# Epoch 12
# ------------------------------
# loss: 0.150342  [    0/60000]
# loss: 0.206318  [ 6400/60000]
# loss: 0.157680  [12800/60000]
# loss: 0.192367  [19200/60000]
# loss: 0.242854  [25600/60000]
# loss: 0.295441  [32000/60000]
# loss: 0.200576  [38400/60000]
# loss: 0.243269  [44800/60000]
# loss: 0.268048  [51200/60000]
# loss: 0.298800  [57600/60000]
# Average Train loss: 0.222479
# Test Error:
#  Accuracy: 87.8%, Avg loss: 0.336071
#
# Epoch 13
# ------------------------------
# loss: 0.153443  [    0/60000]
# loss: 0.191913  [ 6400/60000]
# loss: 0.140998  [12800/60000]
# loss: 0.176672  [19200/60000]
# loss: 0.235165  [25600/60000]
# loss: 0.280781  [32000/60000]
# loss: 0.184881  [38400/60000]
# loss: 0.240086  [44800/60000]
# loss: 0.246997  [51200/60000]
# loss: 0.293155  [57600/60000]
# Average Train loss: 0.213001
# Test Error:
#  Accuracy: 88.0%, Avg loss: 0.334798
#
# Epoch 14
# ------------------------------
# loss: 0.152331  [    0/60000]
# loss: 0.181565  [ 6400/60000]
# loss: 0.139364  [12800/60000]
# loss: 0.171498  [19200/60000]
# loss: 0.220653  [25600/60000]
# loss: 0.262607  [32000/60000]
# loss: 0.180881  [38400/60000]
# loss: 0.232964  [44800/60000]
# loss: 0.248367  [51200/60000]
# loss: 0.274074  [57600/60000]
# Average Train loss: 0.203859
# Test Error:
#  Accuracy: 88.1%, Avg loss: 0.334246
#
# Epoch 15
# ------------------------------
# loss: 0.131969  [    0/60000]
# loss: 0.161911  [ 6400/60000]
# loss: 0.127973  [12800/60000]
# loss: 0.156811  [19200/60000]
# loss: 0.210787  [25600/60000]
# loss: 0.254026  [32000/60000]
# loss: 0.177236  [38400/60000]
# loss: 0.216198  [44800/60000]
# loss: 0.233216  [51200/60000]
# loss: 0.260769  [57600/60000]
# Average Train loss: 0.195293
# Test Error:
#  Accuracy: 87.5%, Avg loss: 0.344398
#
# Accuracy after 15 epochs: 0.875300
#
# Training with model variant: Deeper Model
# Epoch 1
# ------------------------------
# loss: 2.300659  [    0/60000]
# loss: 1.077067  [ 6400/60000]
# loss: 0.662077  [12800/60000]
# loss: 0.771495  [19200/60000]
# loss: 0.603718  [25600/60000]
# loss: 0.505626  [32000/60000]
# loss: 0.535495  [38400/60000]
# loss: 0.603716  [44800/60000]
# loss: 0.589955  [51200/60000]
# loss: 0.477686  [57600/60000]
# Average Train loss: 0.733555
# Test Error:
#  Accuracy: 79.4%, Avg loss: 0.548058
#
# Epoch 2
# ------------------------------
# loss: 0.435906  [    0/60000]
# loss: 0.463400  [ 6400/60000]
# loss: 0.453344  [12800/60000]
# loss: 0.436781  [19200/60000]
# loss: 0.412531  [25600/60000]
# loss: 0.455749  [32000/60000]
# loss: 0.406336  [38400/60000]
# loss: 0.506361  [44800/60000]
# loss: 0.504447  [51200/60000]
# loss: 0.443855  [57600/60000]
# Average Train loss: 0.432347
# Test Error:
#  Accuracy: 81.7%, Avg loss: 0.477241
#
# Epoch 3
# ------------------------------
# loss: 0.343120  [    0/60000]
# loss: 0.364075  [ 6400/60000]
# loss: 0.366992  [12800/60000]
# loss: 0.345336  [19200/60000]
# loss: 0.350009  [25600/60000]
# loss: 0.416847  [32000/60000]
# loss: 0.356126  [38400/60000]
# loss: 0.454485  [44800/60000]
# loss: 0.449496  [51200/60000]
# loss: 0.439685  [57600/60000]
# Average Train loss: 0.378440
# Test Error:
#  Accuracy: 83.1%, Avg loss: 0.445400
#
# Epoch 4
# ------------------------------
# loss: 0.291801  [    0/60000]
# loss: 0.331824  [ 6400/60000]
# loss: 0.283895  [12800/60000]
# loss: 0.301925  [19200/60000]
# loss: 0.323250  [25600/60000]
# loss: 0.395417  [32000/60000]
# loss: 0.327492  [38400/60000]
# loss: 0.426081  [44800/60000]
# loss: 0.401914  [51200/60000]
# loss: 0.416466  [57600/60000]
# Average Train loss: 0.346418
# Test Error:
#  Accuracy: 84.4%, Avg loss: 0.417149
#
# Epoch 5
# ------------------------------
# loss: 0.256471  [    0/60000]
# loss: 0.311794  [ 6400/60000]
# loss: 0.242108  [12800/60000]
# loss: 0.278627  [19200/60000]
# loss: 0.304509  [25600/60000]
# loss: 0.380320  [32000/60000]
# loss: 0.291677  [38400/60000]
# loss: 0.395744  [44800/60000]
# loss: 0.377203  [51200/60000]
# loss: 0.383581  [57600/60000]
# Average Train loss: 0.322710
# Test Error:
#  Accuracy: 85.2%, Avg loss: 0.399499
#
# Epoch 6
# ------------------------------
# loss: 0.236822  [    0/60000]
# loss: 0.295503  [ 6400/60000]
# loss: 0.213838  [12800/60000]
# loss: 0.257131  [19200/60000]
# loss: 0.298590  [25600/60000]
# loss: 0.364726  [32000/60000]
# loss: 0.268714  [38400/60000]
# loss: 0.362285  [44800/60000]
# loss: 0.345684  [51200/60000]
# loss: 0.355243  [57600/60000]
# Average Train loss: 0.303309
# Test Error:
#  Accuracy: 85.7%, Avg loss: 0.392490
#
# Epoch 7
# ------------------------------
# loss: 0.219036  [    0/60000]
# loss: 0.281116  [ 6400/60000]
# loss: 0.195987  [12800/60000]
# loss: 0.247168  [19200/60000]
# loss: 0.292017  [25600/60000]
# loss: 0.345084  [32000/60000]
# loss: 0.247481  [38400/60000]
# loss: 0.350074  [44800/60000]
# loss: 0.318075  [51200/60000]
# loss: 0.345430  [57600/60000]
# Average Train loss: 0.286867
# Test Error:
#  Accuracy: 86.1%, Avg loss: 0.381806
#
# Epoch 8
# ------------------------------
# loss: 0.205756  [    0/60000]
# loss: 0.270106  [ 6400/60000]
# loss: 0.182158  [12800/60000]
# loss: 0.224984  [19200/60000]
# loss: 0.277799  [25600/60000]
# loss: 0.344513  [32000/60000]
# loss: 0.229466  [38400/60000]
# loss: 0.329730  [44800/60000]
# loss: 0.293066  [51200/60000]
# loss: 0.325118  [57600/60000]
# Average Train loss: 0.271961
# Test Error:
#  Accuracy: 85.7%, Avg loss: 0.392403
#
# Epoch 9
# ------------------------------
# loss: 0.203150  [    0/60000]
# loss: 0.261296  [ 6400/60000]
# loss: 0.164411  [12800/60000]
# loss: 0.215217  [19200/60000]
# loss: 0.281145  [25600/60000]
# loss: 0.330057  [32000/60000]
# loss: 0.215986  [38400/60000]
# loss: 0.309469  [44800/60000]
# loss: 0.279978  [51200/60000]
# loss: 0.302744  [57600/60000]
# Average Train loss: 0.258612
# Test Error:
#  Accuracy: 86.0%, Avg loss: 0.381928
#
# Epoch 10
# ------------------------------
# loss: 0.192683  [    0/60000]
# loss: 0.245897  [ 6400/60000]
# loss: 0.159190  [12800/60000]
# loss: 0.203769  [19200/60000]
# loss: 0.265121  [25600/60000]
# loss: 0.328298  [32000/60000]
# loss: 0.214317  [38400/60000]
# loss: 0.268498  [44800/60000]
# loss: 0.257831  [51200/60000]
# loss: 0.298807  [57600/60000]
# Average Train loss: 0.247014
# Test Error:
#  Accuracy: 86.0%, Avg loss: 0.379946
#
# Epoch 11
# ------------------------------
# loss: 0.188623  [    0/60000]
# loss: 0.223600  [ 6400/60000]
# loss: 0.147638  [12800/60000]
# loss: 0.195246  [19200/60000]
# loss: 0.267101  [25600/60000]
# loss: 0.315067  [32000/60000]
# loss: 0.184512  [38400/60000]
# loss: 0.268082  [44800/60000]
# loss: 0.244136  [51200/60000]
# loss: 0.268697  [57600/60000]
# Average Train loss: 0.236250
# Test Error:
#  Accuracy: 86.6%, Avg loss: 0.368893
#
# Epoch 12
# ------------------------------
# loss: 0.181056  [    0/60000]
# loss: 0.219806  [ 6400/60000]
# loss: 0.167226  [12800/60000]
# loss: 0.185918  [19200/60000]
# loss: 0.270489  [25600/60000]
# loss: 0.295561  [32000/60000]
# loss: 0.202592  [38400/60000]
# loss: 0.247998  [44800/60000]
# loss: 0.222832  [51200/60000]
# loss: 0.273399  [57600/60000]
# Average Train loss: 0.226840
# Test Error:
#  Accuracy: 86.9%, Avg loss: 0.369448
#
# Epoch 13
# ------------------------------
# loss: 0.186906  [    0/60000]
# loss: 0.206285  [ 6400/60000]
# loss: 0.163837  [12800/60000]
# loss: 0.166370  [19200/60000]
# loss: 0.267757  [25600/60000]
# loss: 0.286237  [32000/60000]
# loss: 0.224534  [38400/60000]
# loss: 0.243768  [44800/60000]
# loss: 0.224276  [51200/60000]
# loss: 0.255257  [57600/60000]
# Average Train loss: 0.219303
# Test Error:
#  Accuracy: 87.0%, Avg loss: 0.366334
#
# Epoch 14
# ------------------------------
# loss: 0.169000  [    0/60000]
# loss: 0.195839  [ 6400/60000]
# loss: 0.142173  [12800/60000]
# loss: 0.157737  [19200/60000]
# loss: 0.263088  [25600/60000]
# loss: 0.278423  [32000/60000]
# loss: 0.157209  [38400/60000]
# loss: 0.213308  [44800/60000]
# loss: 0.221644  [51200/60000]
# loss: 0.240473  [57600/60000]
# Average Train loss: 0.207512
# Test Error:
#  Accuracy: 87.1%, Avg loss: 0.368911
#
# Epoch 15
# ------------------------------
# loss: 0.163260  [    0/60000]
# loss: 0.192609  [ 6400/60000]
# loss: 0.139300  [12800/60000]
# loss: 0.133180  [19200/60000]
# loss: 0.249960  [25600/60000]
# loss: 0.275630  [32000/60000]
# loss: 0.156362  [38400/60000]
# loss: 0.229238  [44800/60000]
# loss: 0.182705  [51200/60000]
# loss: 0.252407  [57600/60000]
# Average Train loss: 0.199509
# Test Error:
#  Accuracy: 87.0%, Avg loss: 0.373836
#
# Accuracy after 15 epochs: 0.870200
#
# Model Variant: Base Model
# Number of trainable parameters: 669706
# Final Accuracy after 15 epochs: 88.12%
#
# Model Variant: Wider Model
# Number of trainable parameters: 1863690
# Final Accuracy after 15 epochs: 87.53%
#
# Model Variant: Deeper Model
# Number of trainable parameters: 932362
# Final Accuracy after 15 epochs: 87.02%

# %%
# Display the results
for variant in model_variants:
    final_accuracy = results_summary[variant]['accuracy_list'][-1]
    total_params = results_summary[variant]['params_count']
    
    print(f"\nModel Variant: {variant}")
    print(f"Number of trainable parameters: {total_params}")
    print(f"Final Accuracy after 15 epochs: {final_accuracy * 100:.2f}%")
# Out:
# Model Variant: Base Model
# Number of trainable parameters: 669706
# Final Accuracy after 15 epochs: 88.12%
#
# Model Variant: Wider Model
# Number of trainable parameters: 1863690
# Final Accuracy after 15 epochs: 87.53%
#
# Model Variant: Deeper Model
# Number of trainable parameters: 932362
# Final Accuracy after 15 epochs: 87.02%

# %%
# Define distinct colors for each model
colors = ['blue', 'green', 'red']

# Plot training loss for different models
plt.figure(figsize=(14, 6))
for model_name, color in zip(model_variants, colors):
    train_losses = results_summary[model_name]['train_losses']
    plt.plot(range(1, len(train_losses) + 1), train_losses, label=f'Training Loss ({model_name})', color=color)
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss for Different Models', fontweight='bold')
plt.legend()
plt.show()

# Plot test loss for different models
plt.figure(figsize=(14, 6))
for model_name, color in zip(model_variants, colors):
    test_losses = results_summary[model_name]['test_losses']
    plt.plot(range(1, len(test_losses) + 1), test_losses, label=f'Test Loss ({model_name})', color=color)
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Test Loss for Different Models', fontweight='bold')
plt.legend()
plt.show()

# Plot accuracy for different models
plt.figure(figsize=(14, 6))
for model_name, color in zip(model_variants, colors):
    accuracy_list = results_summary[model_name]['accuracy_list']
    plt.plot(range(1, len(accuracy_list) + 1), accuracy_list, label=f'Accuracy ({model_name})', color=color)
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Accuracy for Different Models', fontweight='bold')
plt.legend()
plt.show()

# %% [markdown]
# **Q1.6 (2 points)**
#
# Calculate the mean of the gradients of the loss to all trainable parameters. Plot the gradients curve for the first 100 training steps. What are your observations? Note that this gradients will be saved with the training weight automatically after you call loss.backwards(). Hint: the mean of the gradients decrease.
#
# For more exlanation of q1.7, you could refer to the following simple instructions: https://colab.research.google.com/drive/1XAsyNegGSvMf3_B6MrsXht7-fHqtJ7OW?usp=sharing

# %%
# set random seed
set_seed(42)

# Define the model and optimizer
model = NeuralNetwork().to(device)
optimizer = torch.optim.SGD(model.parameters(), lr=0.01) # Define loss function and optimizer

# %%
def train_with_gradient_tracking(dataloader, model, loss_fn, optimizer, max_steps=100):
    total_samples = len(dataloader.dataset)
    model.train()

    gradient_means = []
    
    for i, (inputs, targets) in enumerate(dataloader):
        inputs, targets = inputs.to(device), targets.to(device)

        # Forward pass: compute predictions and loss
        predictions = model(inputs)
        loss = loss_fn(predictions, targets)

        # Backward pass: compute gradients
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        # Compute mean gradient
        grad_sum = 0
        grad_count = 0
        for param in model.parameters():
            if param.grad is not None:
                grad_sum += param.grad.sum().item()
                grad_count += param.grad.numel()

        avg_gradient = grad_sum / grad_count if grad_count > 0 else 0
        gradient_means.append(avg_gradient)

        if i >= max_steps - 1:
            break

    return gradient_means

# %%
# Model training and gradients tracking
gradient_means = train_with_gradient_tracking(train_dataloader, model, loss_fn, optimizer, 100)


# Plot the mean gradients
plt.figure(figsize=(10, 6))
plt.plot(gradient_means, color='orange', linestyle='--', marker='o')
plt.xlabel('Training Steps')
plt.ylabel('Mean Gradient')
plt.title('Mean Gradient of Loss Across All Parameters Over 100 Training Steps', fontweight='bold')
plt.grid(True)
plt.show()

# %% [markdown]
# **Q1.7 (5 points)**
#
# Modify the network structure and training/test to use a small convolutional neural network instead of an MLP. Discuss your findings with rehgard to convergence, accuracy and number of parameters, relative to MLPs.
#
# Hint: Look at the structure of the CNN in the Workshop 3 examples.

# %%
# Define a Convolutional Neural Network (CNN)
class ConvolutionalNN(nn.Module):
    def __init__(self):
        super(ConvolutionalNN, self).__init__()
        self.features = nn.Sequential(
            nn.Conv2d(1, 16, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Conv2d(16, 32, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2)
        )
        self.classifier = nn.Sequential(
            nn.Flatten(),
            nn.Linear(32 * 7 * 7, 64),
            nn.ReLU(),
            nn.Linear(64, 10)
        )

    def forward(self, x):
        x = self.features(x)
        x = self.classifier(x)
        return x

# %%
# Function to train and evaluate a model with given learning rate and epochs
def run_experiment(lr=0.1, num_epochs=10):
    set_seed(42)
    cnn_model = ConvolutionalNN().to(device)
    optimizer = torch.optim.SGD(cnn_model.parameters(), lr=lr)
    train_losses, test_losses, accuracies = [], [], []
    
    for epoch in range(num_epochs):
        print(f"Epoch {epoch + 1}\n{'-' * 30}")
        train_loss = train(train_dataloader, cnn_model, loss_fn, optimizer)
        test_loss, correct = test(test_dataloader, cnn_model, loss_fn)
        train_losses.append(train_loss)
        test_losses.append(test_loss)
        accuracies.append(correct)
    
    total_params = sum(p.numel() for p in cnn_model.parameters())
    print(f"CNN Model - Accuracy: {correct:.4f}, Total Parameters: {total_params}")
    return train_losses, test_losses, accuracies

# %%
num_epochs = 20

print("Training Convolutional Neural Network (CNN):")
cnn_train_losses, cnn_test_losses, cnn_accuracies = run_experiment(lr=0.1, num_epochs=num_epochs)
print("\nTraining Fully Connected Neural Network (FCNN):")
fcnn_train_losses, fcnn_test_losses, fcnn_accuracies = train_and_test(lr=0.1, epochs=num_epochs)
# Out:
# Training Convolutional Neural Network (CNN):
# Epoch 1
# ------------------------------
# loss: 2.304556  [    0/60000]
# loss: 0.965051  [ 6400/60000]
# loss: 0.635944  [12800/60000]
# loss: 0.752549  [19200/60000]
# loss: 0.613140  [25600/60000]
# loss: 0.581077  [32000/60000]
# loss: 0.502476  [38400/60000]
# loss: 0.523866  [44800/60000]
# loss: 0.645287  [51200/60000]
# loss: 0.454058  [57600/60000]
# Average Train loss: 0.688699
# Test Error:
#  Accuracy: 79.5%, Avg loss: 0.523398
#
# Epoch 2
# ------------------------------
# loss: 0.411013  [    0/60000]
# loss: 0.426862  [ 6400/60000]
# loss: 0.311340  [12800/60000]
# loss: 0.454015  [19200/60000]
# loss: 0.371598  [25600/60000]
# loss: 0.427330  [32000/60000]
# loss: 0.332584  [38400/60000]
# loss: 0.442286  [44800/60000]
# loss: 0.564446  [51200/60000]
# loss: 0.364053  [57600/60000]
# Average Train loss: 0.394739
# Test Error:
#  Accuracy: 85.1%, Avg loss: 0.400945
#
# Epoch 3
# ------------------------------
# loss: 0.237436  [    0/60000]
# loss: 0.348992  [ 6400/60000]
# loss: 0.260777  [12800/60000]
# loss: 0.402684  [19200/60000]
# loss: 0.303330  [25600/60000]
# loss: 0.398112  [32000/60000]
# loss: 0.299213  [38400/60000]
# loss: 0.381968  [44800/60000]
# loss: 0.487724  [51200/60000]
# loss: 0.327347  [57600/60000]
# Average Train loss: 0.337489
# Test Error:
#  Accuracy: 87.0%, Avg loss: 0.353821
#
# Epoch 4
# ------------------------------
# loss: 0.200808  [    0/60000]
# loss: 0.298250  [ 6400/60000]
# loss: 0.230259  [12800/60000]
# loss: 0.355867  [19200/60000]
# loss: 0.291581  [25600/60000]
# loss: 0.381343  [32000/60000]
# loss: 0.284004  [38400/60000]
# loss: 0.341538  [44800/60000]
# loss: 0.441110  [51200/60000]
# loss: 0.307330  [57600/60000]
# Average Train loss: 0.305707
# Test Error:
#  Accuracy: 87.9%, Avg loss: 0.326487
#
# Epoch 5
# ------------------------------
# loss: 0.197312  [    0/60000]
# loss: 0.243938  [ 6400/60000]
# loss: 0.187032  [12800/60000]
# loss: 0.330555  [19200/60000]
# loss: 0.269863  [25600/60000]
# loss: 0.360913  [32000/60000]
# loss: 0.285053  [38400/60000]
# loss: 0.301490  [44800/60000]
# loss: 0.395924  [51200/60000]
# loss: 0.291860  [57600/60000]
# Average Train loss: 0.282382
# Test Error:
#  Accuracy: 88.5%, Avg loss: 0.311260
#
# Epoch 6
# ------------------------------
# loss: 0.185101  [    0/60000]
# loss: 0.232213  [ 6400/60000]
# loss: 0.157879  [12800/60000]
# loss: 0.292108  [19200/60000]
# loss: 0.273945  [25600/60000]
# loss: 0.334664  [32000/60000]
# loss: 0.273488  [38400/60000]
# loss: 0.270914  [44800/60000]
# loss: 0.341841  [51200/60000]
# loss: 0.266144  [57600/60000]
# Average Train loss: 0.263365
# Test Error:
#  Accuracy: 89.0%, Avg loss: 0.297783
#
# Epoch 7
# ------------------------------
# loss: 0.171947  [    0/60000]
# loss: 0.221493  [ 6400/60000]
# loss: 0.132124  [12800/60000]
# loss: 0.267376  [19200/60000]
# loss: 0.251208  [25600/60000]
# loss: 0.293161  [32000/60000]
# loss: 0.263910  [38400/60000]
# loss: 0.268571  [44800/60000]
# loss: 0.311495  [51200/60000]
# loss: 0.240840  [57600/60000]
# Average Train loss: 0.247556
# Test Error:
#  Accuracy: 89.2%, Avg loss: 0.289632
#
# Epoch 8
# ------------------------------
# loss: 0.146796  [    0/60000]
# loss: 0.213801  [ 6400/60000]
# loss: 0.112688  [12800/60000]
# loss: 0.243323  [19200/60000]
# loss: 0.256967  [25600/60000]
# loss: 0.276276  [32000/60000]
# loss: 0.244051  [38400/60000]
# loss: 0.224020  [44800/60000]
# loss: 0.268702  [51200/60000]
# loss: 0.219977  [57600/60000]
# Average Train loss: 0.234408
# Test Error:
#  Accuracy: 89.7%, Avg loss: 0.278422
#
# Epoch 9
# ------------------------------
# loss: 0.133150  [    0/60000]
# loss: 0.199572  [ 6400/60000]
# loss: 0.103384  [12800/60000]
# loss: 0.224242  [19200/60000]
# loss: 0.260430  [25600/60000]
# loss: 0.259984  [32000/60000]
# loss: 0.232204  [38400/60000]
# loss: 0.233078  [44800/60000]
# loss: 0.249199  [51200/60000]
# loss: 0.211329  [57600/60000]
# Average Train loss: 0.222027
# Test Error:
#  Accuracy: 90.0%, Avg loss: 0.270786
#
# Epoch 10
# ------------------------------
# loss: 0.131857  [    0/60000]
# loss: 0.178424  [ 6400/60000]
# loss: 0.103715  [12800/60000]
# loss: 0.206973  [19200/60000]
# loss: 0.250893  [25600/60000]
# loss: 0.258982  [32000/60000]
# loss: 0.236284  [38400/60000]
# loss: 0.220304  [44800/60000]
# loss: 0.238342  [51200/60000]
# loss: 0.200376  [57600/60000]
# Average Train loss: 0.211438
# Test Error:
#  Accuracy: 90.1%, Avg loss: 0.270366
#
# Epoch 11
# ------------------------------
# loss: 0.113663  [    0/60000]
# loss: 0.161193  [ 6400/60000]
# loss: 0.096015  [12800/60000]
# loss: 0.182719  [19200/60000]
# loss: 0.254028  [25600/60000]
# loss: 0.241054  [32000/60000]
# loss: 0.201498  [38400/60000]
# loss: 0.208776  [44800/60000]
# loss: 0.214535  [51200/60000]
# loss: 0.189866  [57600/60000]
# Average Train loss: 0.200896
# Test Error:
#  Accuracy: 90.4%, Avg loss: 0.265424
#
# Epoch 12
# ------------------------------
# loss: 0.102870  [    0/60000]
# loss: 0.149581  [ 6400/60000]
# loss: 0.094184  [12800/60000]
# loss: 0.173904  [19200/60000]
# loss: 0.263218  [25600/60000]
# loss: 0.222781  [32000/60000]
# loss: 0.199582  [38400/60000]
# loss: 0.202906  [44800/60000]
# loss: 0.209398  [51200/60000]
# loss: 0.182839  [57600/60000]
# Average Train loss: 0.190959
# Test Error:
#  Accuracy: 90.6%, Avg loss: 0.266258
#
# Epoch 13
# ------------------------------
# loss: 0.099653  [    0/60000]
# loss: 0.132410  [ 6400/60000]
# loss: 0.087103  [12800/60000]
# loss: 0.150534  [19200/60000]
# loss: 0.239566  [25600/60000]
# loss: 0.223902  [32000/60000]
# loss: 0.188589  [38400/60000]
# loss: 0.185316  [44800/60000]
# loss: 0.190953  [51200/60000]
# loss: 0.184663  [57600/60000]
# Average Train loss: 0.181433
# Test Error:
#  Accuracy: 90.8%, Avg loss: 0.265836
#
# Epoch 14
# ------------------------------
# loss: 0.103491  [    0/60000]
# loss: 0.120382  [ 6400/60000]
# loss: 0.079381  [12800/60000]
# loss: 0.138490  [19200/60000]
# loss: 0.224855  [25600/60000]
# loss: 0.218741  [32000/60000]
# loss: 0.176150  [38400/60000]
# loss: 0.186444  [44800/60000]
# loss: 0.182376  [51200/60000]
# loss: 0.172730  [57600/60000]
# Average Train loss: 0.171807
# Test Error:
#  Accuracy: 90.8%, Avg loss: 0.268838
#
# Epoch 15
# ------------------------------
# loss: 0.082942  [    0/60000]
# loss: 0.111019  [ 6400/60000]
# loss: 0.060169  [12800/60000]
# loss: 0.127864  [19200/60000]
# loss: 0.211518  [25600/60000]
# loss: 0.210993  [32000/60000]
# loss: 0.159506  [38400/60000]
# loss: 0.193266  [44800/60000]
# loss: 0.164365  [51200/60000]
# loss: 0.168814  [57600/60000]
# Average Train loss: 0.163277
# Test Error:
#  Accuracy: 90.7%, Avg loss: 0.279206
#
# Epoch 16
# ------------------------------
# loss: 0.074362  [    0/60000]
# loss: 0.100500  [ 6400/60000]
# loss: 0.060735  [12800/60000]
# loss: 0.129030  [19200/60000]
# loss: 0.194699  [25600/60000]
# loss: 0.217407  [32000/60000]
# loss: 0.153239  [38400/60000]
# loss: 0.185737  [44800/60000]
# loss: 0.158111  [51200/60000]
# loss: 0.143953  [57600/60000]
# Average Train loss: 0.155233
# Test Error:
#  Accuracy: 90.8%, Avg loss: 0.280669
#
# Epoch 17
# ------------------------------
# loss: 0.075113  [    0/60000]
# loss: 0.090914  [ 6400/60000]
# loss: 0.047624  [12800/60000]
# loss: 0.112132  [19200/60000]
# loss: 0.194115  [25600/60000]
# loss: 0.220046  [32000/60000]
# loss: 0.137582  [38400/60000]
# loss: 0.178329  [44800/60000]
# loss: 0.149345  [51200/60000]
# loss: 0.141660  [57600/60000]
# Average Train loss: 0.146538
# Test Error:
#  Accuracy: 90.6%, Avg loss: 0.292619
#
# Epoch 18
# ------------------------------
# loss: 0.063257  [    0/60000]
# loss: 0.081362  [ 6400/60000]
# loss: 0.042915  [12800/60000]
# loss: 0.100733  [19200/60000]
# loss: 0.169806  [25600/60000]
# loss: 0.224705  [32000/60000]
# loss: 0.145814  [38400/60000]
# loss: 0.176403  [44800/60000]
# loss: 0.146652  [51200/60000]
# loss: 0.125926  [57600/60000]
# Average Train loss: 0.138690
# Test Error:
#  Accuracy: 90.6%, Avg loss: 0.302117
#
# Epoch 19
# ------------------------------
# loss: 0.052035  [    0/60000]
# loss: 0.074080  [ 6400/60000]
# loss: 0.038888  [12800/60000]
# loss: 0.096723  [19200/60000]
# loss: 0.121053  [25600/60000]
# loss: 0.192436  [32000/60000]
# loss: 0.130865  [38400/60000]
# loss: 0.162153  [44800/60000]
# loss: 0.087907  [51200/60000]
# loss: 0.126715  [57600/60000]
# Average Train loss: 0.130407
# Test Error:
#  Accuracy: 90.7%, Avg loss: 0.309458
#
# Epoch 20
# ------------------------------
# loss: 0.061013  [    0/60000]
# loss: 0.066961  [ 6400/60000]
# loss: 0.036572  [12800/60000]
# loss: 0.108299  [19200/60000]
# loss: 0.115450  [25600/60000]
# loss: 0.163205  [32000/60000]
# loss: 0.126984  [38400/60000]
# loss: 0.169530  [44800/60000]
# loss: 0.119807  [51200/60000]
# loss: 0.111160  [57600/60000]
# Average Train loss: 0.124146
# Test Error:
#  Accuracy: 90.6%, Avg loss: 0.319124
#
# CNN Model - Accuracy: 0.9058, Total Parameters: 105866
#
# Training Fully Connected Neural Network (FCNN):
# Learning rate: 0.1
# ------------------------------
# Epoch 1
# ------------------------------
# loss: 2.298730  [    0/60000]
# loss: 0.908623  [ 6400/60000]
# loss: 0.580196  [12800/60000]
# loss: 0.720629  [19200/60000]
# loss: 0.614350  [25600/60000]
# loss: 0.500302  [32000/60000]
# loss: 0.540581  [38400/60000]
# loss: 0.599433  [44800/60000]
# loss: 0.616562  [51200/60000]
# loss: 0.458594  [57600/60000]
# Average Train loss: 0.654657
# Test Error:
#  Accuracy: 78.1%, Avg loss: 0.571193
#
# Epoch 2
# ------------------------------
# loss: 0.465054  [    0/60000]
# loss: 0.442642  [ 6400/60000]
# loss: 0.377082  [12800/60000]
# loss: 0.440151  [19200/60000]
# loss: 0.403445  [25600/60000]
# loss: 0.436655  [32000/60000]
# loss: 0.406358  [38400/60000]
# loss: 0.507337  [44800/60000]
# loss: 0.526519  [51200/60000]
# loss: 0.432994  [57600/60000]
# Average Train loss: 0.424438
# Test Error:
#  Accuracy: 81.3%, Avg loss: 0.488511
#
# Epoch 3
# ------------------------------
# loss: 0.358920  [    0/60000]
# loss: 0.366159  [ 6400/60000]
# loss: 0.310650  [12800/60000]
# loss: 0.365913  [19200/60000]
# loss: 0.336239  [25600/60000]
# loss: 0.408728  [32000/60000]
# loss: 0.349020  [38400/60000]
# loss: 0.467654  [44800/60000]
# loss: 0.465646  [51200/60000]
# loss: 0.415533  [57600/60000]
# Average Train loss: 0.375505
# Test Error:
#  Accuracy: 83.2%, Avg loss: 0.446801
#
# Epoch 4
# ------------------------------
# loss: 0.290721  [    0/60000]
# loss: 0.334928  [ 6400/60000]
# loss: 0.265934  [12800/60000]
# loss: 0.319810  [19200/60000]
# loss: 0.319318  [25600/60000]
# loss: 0.390072  [32000/60000]
# loss: 0.320641  [38400/60000]
# loss: 0.418341  [44800/60000]
# loss: 0.431594  [51200/60000]
# loss: 0.401941  [57600/60000]
# Average Train loss: 0.344942
# Test Error:
#  Accuracy: 84.4%, Avg loss: 0.415021
#
# Epoch 5
# ------------------------------
# loss: 0.251623  [    0/60000]
# loss: 0.310359  [ 6400/60000]
# loss: 0.229984  [12800/60000]
# loss: 0.302930  [19200/60000]
# loss: 0.300974  [25600/60000]
# loss: 0.375038  [32000/60000]
# loss: 0.295272  [38400/60000]
# loss: 0.381145  [44800/60000]
# loss: 0.404316  [51200/60000]
# loss: 0.380406  [57600/60000]
# Average Train loss: 0.322477
# Test Error:
#  Accuracy: 85.7%, Avg loss: 0.389594
#
# Epoch 6
# ------------------------------
# loss: 0.223772  [    0/60000]
# loss: 0.287521  [ 6400/60000]
# loss: 0.215778  [12800/60000]
# loss: 0.271372  [19200/60000]
# loss: 0.289058  [25600/60000]
# loss: 0.365862  [32000/60000]
# loss: 0.280939  [38400/60000]
# loss: 0.363203  [44800/60000]
# loss: 0.384423  [51200/60000]
# loss: 0.368786  [57600/60000]
# Average Train loss: 0.304477
# Test Error:
#  Accuracy: 86.0%, Avg loss: 0.371941
#
# Epoch 7
# ------------------------------
# loss: 0.213792  [    0/60000]
# loss: 0.273293  [ 6400/60000]
# loss: 0.195239  [12800/60000]
# loss: 0.252823  [19200/60000]
# loss: 0.280653  [25600/60000]
# loss: 0.348211  [32000/60000]
# loss: 0.256258  [38400/60000]
# loss: 0.328084  [44800/60000]
# loss: 0.371048  [51200/60000]
# loss: 0.348812  [57600/60000]
# Average Train loss: 0.289304
# Test Error:
#  Accuracy: 86.6%, Avg loss: 0.362419
#
# Epoch 8
# ------------------------------
# loss: 0.203672  [    0/60000]
# loss: 0.258862  [ 6400/60000]
# loss: 0.187886  [12800/60000]
# loss: 0.241832  [19200/60000]
# loss: 0.277331  [25600/60000]
# loss: 0.337186  [32000/60000]
# loss: 0.243633  [38400/60000]
# loss: 0.309428  [44800/60000]
# loss: 0.347340  [51200/60000]
# loss: 0.343401  [57600/60000]
# Average Train loss: 0.275754
# Test Error:
#  Accuracy: 87.1%, Avg loss: 0.355105
#
# Epoch 9
# ------------------------------
# loss: 0.190051  [    0/60000]
# loss: 0.250311  [ 6400/60000]
# loss: 0.179111  [12800/60000]
# loss: 0.227047  [19200/60000]
# loss: 0.265265  [25600/60000]
# loss: 0.324286  [32000/60000]
# loss: 0.235161  [38400/60000]
# loss: 0.303972  [44800/60000]
# loss: 0.339473  [51200/60000]
# loss: 0.336972  [57600/60000]
# Average Train loss: 0.263608
# Test Error:
#  Accuracy: 87.3%, Avg loss: 0.350590
#
# Epoch 10
# ------------------------------
# loss: 0.182916  [    0/60000]
# loss: 0.235876  [ 6400/60000]
# loss: 0.168496  [12800/60000]
# loss: 0.221832  [19200/60000]
# loss: 0.257252  [25600/60000]
# loss: 0.307938  [32000/60000]
# loss: 0.216700  [38400/60000]
# loss: 0.296519  [44800/60000]
# loss: 0.311959  [51200/60000]
# loss: 0.313996  [57600/60000]
# Average Train loss: 0.252720
# Test Error:
#  Accuracy: 87.8%, Avg loss: 0.341121
#
# Epoch 11
# ------------------------------
# loss: 0.170423  [    0/60000]
# loss: 0.223069  [ 6400/60000]
# loss: 0.163827  [12800/60000]
# loss: 0.205821  [19200/60000]
# loss: 0.244937  [25600/60000]
# loss: 0.293522  [32000/60000]
# loss: 0.205827  [38400/60000]
# loss: 0.270297  [44800/60000]
# loss: 0.293723  [51200/60000]
# loss: 0.304437  [57600/60000]
# Average Train loss: 0.242261
# Test Error:
#  Accuracy: 87.9%, Avg loss: 0.339731
#
# Epoch 12
# ------------------------------
# loss: 0.178047  [    0/60000]
# loss: 0.218225  [ 6400/60000]
# loss: 0.163225  [12800/60000]
# loss: 0.193094  [19200/60000]
# loss: 0.256125  [25600/60000]
# loss: 0.282314  [32000/60000]
# loss: 0.194421  [38400/60000]
# loss: 0.263575  [44800/60000]
# loss: 0.279800  [51200/60000]
# loss: 0.303665  [57600/60000]
# Average Train loss: 0.232800
# Test Error:
#  Accuracy: 87.8%, Avg loss: 0.342771
#
# Epoch 13
# ------------------------------
# loss: 0.181593  [    0/60000]
# loss: 0.201415  [ 6400/60000]
# loss: 0.157234  [12800/60000]
# loss: 0.187879  [19200/60000]
# loss: 0.243177  [25600/60000]
# loss: 0.268999  [32000/60000]
# loss: 0.189197  [38400/60000]
# loss: 0.258763  [44800/60000]
# loss: 0.264539  [51200/60000]
# loss: 0.276674  [57600/60000]
# Average Train loss: 0.223409
# Test Error:
#  Accuracy: 87.7%, Avg loss: 0.346049
#
# Epoch 14
# ------------------------------
# loss: 0.182112  [    0/60000]
# loss: 0.193605  [ 6400/60000]
# loss: 0.150290  [12800/60000]
# loss: 0.179166  [19200/60000]
# loss: 0.242892  [25600/60000]
# loss: 0.246919  [32000/60000]
# loss: 0.179747  [38400/60000]
# loss: 0.249119  [44800/60000]
# loss: 0.260210  [51200/60000]
# loss: 0.254636  [57600/60000]
# Average Train loss: 0.214480
# Test Error:
#  Accuracy: 87.9%, Avg loss: 0.340266
#
# Epoch 15
# ------------------------------
# loss: 0.165276  [    0/60000]
# loss: 0.185297  [ 6400/60000]
# loss: 0.141397  [12800/60000]
# loss: 0.176628  [19200/60000]
# loss: 0.237437  [25600/60000]
# loss: 0.229595  [32000/60000]
# loss: 0.170295  [38400/60000]
# loss: 0.253307  [44800/60000]
# loss: 0.253614  [51200/60000]
# loss: 0.235814  [57600/60000]
# Average Train loss: 0.206003
# Test Error:
#  Accuracy: 88.1%, Avg loss: 0.340398
#
# Epoch 16
# ------------------------------
# loss: 0.158656  [    0/60000]
# loss: 0.178394  [ 6400/60000]
# loss: 0.131545  [12800/60000]
# loss: 0.164973  [19200/60000]
# loss: 0.231347  [25600/60000]
# loss: 0.213649  [32000/60000]
# loss: 0.169106  [38400/60000]
# loss: 0.238610  [44800/60000]
# loss: 0.242297  [51200/60000]
# loss: 0.229467  [57600/60000]
# Average Train loss: 0.198107
# Test Error:
#  Accuracy: 87.9%, Avg loss: 0.339957
#
# Epoch 17
# ------------------------------
# loss: 0.155545  [    0/60000]
# loss: 0.170049  [ 6400/60000]
# loss: 0.128804  [12800/60000]
# loss: 0.149593  [19200/60000]
# loss: 0.218744  [25600/60000]
# loss: 0.213341  [32000/60000]
# loss: 0.162126  [38400/60000]
# loss: 0.253509  [44800/60000]
# loss: 0.229681  [51200/60000]
# loss: 0.227891  [57600/60000]
# Average Train loss: 0.190538
# Test Error:
#  Accuracy: 88.0%, Avg loss: 0.344605
#
# Epoch 18
# ------------------------------
# loss: 0.154638  [    0/60000]
# loss: 0.170945  [ 6400/60000]
# loss: 0.124243  [12800/60000]
# loss: 0.143868  [19200/60000]
# loss: 0.229773  [25600/60000]
# loss: 0.206859  [32000/60000]
# loss: 0.161093  [38400/60000]
# loss: 0.256611  [44800/60000]
# loss: 0.222545  [51200/60000]
# loss: 0.213766  [57600/60000]
# Average Train loss: 0.183057
# Test Error:
#  Accuracy: 87.7%, Avg loss: 0.349274
#
# Epoch 19
# ------------------------------
# loss: 0.148598  [    0/60000]
# loss: 0.152995  [ 6400/60000]
# loss: 0.112899  [12800/60000]
# loss: 0.132888  [19200/60000]
# loss: 0.219276  [25600/60000]
# loss: 0.199966  [32000/60000]
# loss: 0.146067  [38400/60000]
# loss: 0.229262  [44800/60000]
# loss: 0.206589  [51200/60000]
# loss: 0.205461  [57600/60000]
# Average Train loss: 0.175241
# Test Error:
#  Accuracy: 87.9%, Avg loss: 0.346082
#
# Epoch 20
# ------------------------------
# loss: 0.143650  [    0/60000]
# loss: 0.151762  [ 6400/60000]
# loss: 0.111364  [12800/60000]
# loss: 0.140302  [19200/60000]
# loss: 0.198349  [25600/60000]
# loss: 0.198918  [32000/60000]
# loss: 0.151464  [38400/60000]
# loss: 0.245490  [44800/60000]
# loss: 0.202096  [51200/60000]
# loss: 0.212197  [57600/60000]
# Average Train loss: 0.168135
# Test Error:
#  Accuracy: 87.5%, Avg loss: 0.357775
#
# Accuracy after 20 epochs: 0.875
# Finish running!

# %%
# Comparison plots
epochs_range = range(1, num_epochs + 1)

# Plot training loss comparison
plt.figure(figsize=(14, 6))
plt.plot(epochs_range, cnn_train_losses, label='CNN Training Loss', color='purple', linestyle='-', marker='o')
plt.plot(epochs_range, fcnn_train_losses, label='FCNN Training Loss', color='orange', linestyle='-', marker='x')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss Comparison', fontweight='bold')
plt.legend()
plt.grid(True)
plt.xticks(epochs_range)

# Plot test loss comparison
plt.figure(figsize=(14, 6))
plt.plot(epochs_range, cnn_test_losses, label='CNN Test Loss', color='purple', linestyle='-', marker='o')
plt.plot(epochs_range, fcnn_test_losses, label='FCNN Test Loss', color='orange', linestyle='-', marker='x')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Test Loss Comparison', fontweight='bold')
plt.legend()
plt.grid(True)
plt.xticks(epochs_range)

# Plot accuracy comparison
plt.figure(figsize=(14, 6))
plt.plot(epochs_range, cnn_accuracies, label='CNN Accuracy', color='purple', linestyle='-', marker='o')
plt.plot(epochs_range, fcnn_accuracies, label='FCNN Accuracy', color='orange', linestyle='-', marker='x')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Accuracy Comparison', fontweight='bold')
plt.legend()
plt.grid(True)
plt.xticks(epochs_range)

plt.show()

# %%
# Print out performance details
cnn_model = ConvolutionalNN().to(device)
fcnn_model = NeuralNetwork().to(device)

print(f"Model: CNN, Trainable Parameters: {number_of_trainable_params(cnn_model)}")
print(f"Accuracy after {num_epochs} epochs: {round(cnn_accuracies[-1] * 100, 2)}%\n")

print(f"Model: FCNN, Trainable Parameters: {number_of_trainable_params(fcnn_model)}")
print(f"Accuracy after {num_epochs} epochs: {round(fcnn_accuracies[-1] * 100, 2)}%\n")
# Out:
# Model: CNN, Trainable Parameters: 105866
# Accuracy after 20 epochs: 90.58%
#
# Model: FCNN, Trainable Parameters: 669706
# Accuracy after 20 epochs: 87.5%
